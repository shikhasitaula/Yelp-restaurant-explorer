# %%
import pandas as pd
import requests
import json

# %%
# Import API key
from api import API_key

# %%
url = "https://api.yelp.com/v3/businesses/search"

# %%
headers = {
        'Authorization': 'Bearer ' + API_key,
        'Content-Type': 'application/json'
    }

# %%
states = ['New York', 'California']
restaurants= []

# %%
for state in states:
    params = {'location': state,
          'limit': 50
        }

# %%
 # Pretty print JSON for all launchpads
response = requests.get(url,  headers=headers, params=params).json()
print(json.dumps(response, indent=4, sort_keys=False))

if 'businesses' in response:
        restaurants.extend(response['businesses'])
# Out:
# {
#     "businesses": [
#         {
#             "id": "9ZURLR_1ys3lN3Li8E_C0w",
#             "alias": "heirloom-fresno-2",
#             "name": "Heirloom",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/7fjE8hBYMvkA9U_DGB1jkA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/heirloom-fresno-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1976,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.85648251011611,
#                 "longitude": -119.78372133927978
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "8398 N Fresno St",
#                 "address2": "Ste 101",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "8398 N Fresno St",
#                     "Ste 101",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15592289735",
#             "display_phone": "(559) 228-9735",
#             "distance": 62366.05109715377
#         },
#         {
#             "id": "xiPYoKcZ-QacPjrvUFRkpQ",
#             "alias": "the-annex-kitchen-fresno-2",
#             "name": "The Annex Kitchen",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Y-UPgyUgN9TEIwTGA0Irhg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-annex-kitchen-fresno-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1529,
#             "categories": [
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.80758,
#                 "longitude": -119.83229
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "2257 W Shaw Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2257 W Shaw Ave",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15592488512",
#             "display_phone": "(559) 248-8512",
#             "distance": 69284.52751119724
#         },
#         {
#             "id": "_9aI8_nUwnBTSlPEbWNdHw",
#             "alias": "mochuelo-fresno",
#             "name": "Mochuelo",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/7JWSi-fKZ2oZHLE_d2pzRw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mochuelo-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 391,
#             "categories": [
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 },
#                 {
#                     "alias": "spanish",
#                     "title": "Spanish"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.807753,
#                 "longitude": -119.833184
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "2305 W Shaw Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2305 W Shaw Ave",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15593485555",
#             "display_phone": "(559) 348-5555",
#             "distance": 69334.71745495437
#         },
#         {
#             "id": "_Ae3d3r7Ut-VAUoBcFYs7Q",
#             "alias": "saizon-fresno",
#             "name": "Saizon",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/K7CSA_GW8tRh-rceuLMVMQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/saizon-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 323,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.86728041008362,
#                 "longitude": -119.7304528449808
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "2894 E Shepherd Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2894 E Shepherd Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15595529688",
#             "display_phone": "(559) 552-9688",
#             "distance": 58327.86771931272
#         },
#         {
#             "id": "SUrXfIWTrfwbQB4UD98-0w",
#             "alias": "the-lime-lite-fresno",
#             "name": "The Lime Lite",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/N4-t5RbnclHDTNFMjHMs6g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-lime-lite-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 468,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.808791,
#                 "longitude": -119.809706
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1054 W Shaw Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1054 W Shaw Ave",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15592241054",
#             "display_phone": "(559) 224-1054",
#             "distance": 67857.03754247453
#         },
#         {
#             "id": "Sfpb-erwFWTp_HJ3kNRYWA",
#             "alias": "coltons-social-house-clovis",
#             "name": "Colton's Social House",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ENIJswpI96BZ18WHWgkp6g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/coltons-social-house-clovis?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1529,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.80802,
#                 "longitude": -119.69427
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "1150 Shaw Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Clovis",
#                 "zip_code": "93612",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1150 Shaw Ave",
#                     "Clovis, CA 93612"
#                 ]
#             },
#             "phone": "+15597216655",
#             "display_phone": "(559) 721-6655",
#             "distance": 61663.21924519196
#         },
#         {
#             "id": "0agq0wMl5TAyH4fSxN8NUA",
#             "alias": "skadi-mammoth-lakes-2",
#             "name": "SKADI",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/f9dDghIjtnguBjWA88ISjw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/skadi-mammoth-lakes-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 422,
#             "categories": [
#                 {
#                     "alias": "modern_european",
#                     "title": "Modern European"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 37.6512,
#                 "longitude": -118.9829
#             },
#             "transactions": [],
#             "price": "$$$$",
#             "location": {
#                 "address1": "94 Berner St",
#                 "address2": "Ste A",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "94 Berner St",
#                     "Ste A",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609140962",
#             "display_phone": "(760) 914-0962",
#             "distance": 51284.62489949966
#         },
#         {
#             "id": "GPP5E-f1dzAN08jNogYCjw",
#             "alias": "smokehouse-41-oakhurst",
#             "name": "Smokehouse 41",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/HcfpJdd-Xhy9KsNIZs27dw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/smokehouse-41-oakhurst?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 721,
#             "categories": [
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 },
#                 {
#                     "alias": "smokehouse",
#                     "title": "Smokehouse"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.33914,
#                 "longitude": -119.64334
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "40713 Hwy 41",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Oakhurst",
#                 "zip_code": "93644",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "40713 Hwy 41",
#                     "Oakhurst, CA 93644"
#                 ]
#             },
#             "phone": "+15596422271",
#             "display_phone": "(559) 642-2271",
#             "distance": 30971.077571383135
#         },
#         {
#             "id": "jGBBu6ppRzyPjerTLr_PaQ",
#             "alias": "sabor-cocina-latina-and-bar-fresno",
#             "name": "Sabor Cocina Latina & Bar",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/EeGd4sikgevaJmyYojhzLw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/sabor-cocina-latina-and-bar-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 347,
#             "categories": [
#                 {
#                     "alias": "latin",
#                     "title": "Latin American"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.851711,
#                 "longitude": -119.806469
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "7845 N Palm Ave",
#                 "address2": "Ste 104",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "7845 N Palm Ave",
#                     "Ste 104",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15593751644",
#             "display_phone": "(559) 375-1644",
#             "distance": 64135.99001913438
#         },
#         {
#             "id": "Y58wkqUQ_-Kz8_o8qnP15A",
#             "alias": "charles-street-dinner-house-mariposa",
#             "name": "Charles Street Dinner House",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/CfDdO02388XApD2oEqQgCQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/charles-street-dinner-house-mariposa?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 549,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.48545467039154,
#                 "longitude": -119.96607841142622
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "5043 Hwy 140 and 7th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mariposa",
#                 "zip_code": "95338",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "5043 Hwy 140 and 7th St",
#                     "Mariposa, CA 95338"
#                 ]
#             },
#             "phone": "+12099662366",
#             "display_phone": "(209) 966-2366",
#             "distance": 63215.82307229185
#         },
#         {
#             "id": "ivx1E6-pW2TjxSG89fQagw",
#             "alias": "red-apple-cafe-fresno",
#             "name": "Red Apple Cafe",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vauGirZt92gfMCWChZYcRQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/red-apple-cafe-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1287,
#             "categories": [
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "cafes",
#                     "title": "Cafes"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.837659,
#                 "longitude": -119.801605
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "488 W Herndon Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93650",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "488 W Herndon Ave",
#                     "Fresno, CA 93650"
#                 ]
#             },
#             "phone": "+15592611505",
#             "display_phone": "(559) 261-1505",
#             "distance": 64989.236683342264
#         },
#         {
#             "id": "gwANdrsPZr3ZVAqN52vwqg",
#             "alias": "the-elderberry-house-oakhurst-2",
#             "name": "The Elderberry House",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/NkGEpjKf31sgXaT_XHassQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-elderberry-house-oakhurst-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 283,
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.327100397143525,
#                 "longitude": -119.66091834110446
#             },
#             "transactions": [],
#             "price": "$$$$",
#             "location": {
#                 "address1": "48688 Victoria Ln",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Oakhurst",
#                 "zip_code": "93644",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "48688 Victoria Ln",
#                     "Oakhurst, CA 93644"
#                 ]
#             },
#             "phone": "+15596836800",
#             "display_phone": "(559) 683-6800",
#             "distance": 32143.065198151613
#         },
#         {
#             "id": "Ollnz3tVka1bMFbryAnn0g",
#             "alias": "hino-oishi-fresno",
#             "name": "Hino Oishi",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/TmbE4rKeDRjnHBGFYl92Cw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hino-oishi-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1078,
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8116445316553,
#                 "longitude": -119.73440675283616
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "3091 E Campus Pointe Dr",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93710",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3091 E Campus Pointe Dr",
#                     "Fresno, CA 93710"
#                 ]
#             },
#             "phone": "+15597654657",
#             "display_phone": "(559) 765-4657",
#             "distance": 63392.155030950526
#         },
#         {
#             "id": "Oe2yeFzamknh4NvRBoJWlw",
#             "alias": "13-prime-steak-clovis-3",
#             "name": "13 Prime Steak",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/gfoazhGJpgafm2_mATiArA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/13-prime-steak-clovis-3?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 431,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.85358,
#                 "longitude": -119.72805
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1345 N Willow Ave",
#                 "address2": "Ste 190",
#                 "address3": null,
#                 "city": "Clovis",
#                 "zip_code": "93619",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1345 N Willow Ave",
#                     "Ste 190",
#                     "Clovis, CA 93619"
#                 ]
#             },
#             "phone": "+15592161313",
#             "display_phone": "(559) 216-1313",
#             "distance": 59356.54690292182
#         },
#         {
#             "id": "dCAnqtdMqbvZXIJt2FA22g",
#             "alias": "the-mogul-restaurant-mammoth-lakes",
#             "name": "The Mogul Restaurant",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/gGjl6hqMnW2QlZ9PTlIQ1A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-mogul-restaurant-mammoth-lakes?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 609,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.64519,
#                 "longitude": -118.96671
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "1528 Tavern Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1528 Tavern Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609343039",
#             "display_phone": "(760) 934-3039",
#             "distance": 51550.001167560644
#         },
#         {
#             "id": "Vp4h70Ok9RYj8lAAUOfqAQ",
#             "alias": "batter-up-pancakes-fresno-2",
#             "name": "Batter Up Pancakes",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/JOl3AbgKik3_SFYEYd9zUg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/batter-up-pancakes-fresno-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1420,
#             "categories": [
#                 {
#                     "alias": "pancakes",
#                     "title": "Pancakes"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8525455,
#                 "longitude": -119.7582005
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "8029 N Cedar Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "8029 N Cedar Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15594401221",
#             "display_phone": "(559) 440-1221",
#             "distance": 61177.632336838775
#         },
#         {
#             "id": "WlJqfuAfu9Mo3E-tZznsKw",
#             "alias": "mammoth-rock-brasserie-mammoth-lakes-2",
#             "name": "Mammoth Rock Brasserie",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wT3rBmpTTrc3fdm2p7Tnkg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mammoth-rock-brasserie-mammoth-lakes-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 405,
#             "categories": [
#                 {
#                     "alias": "brasseries",
#                     "title": "Brasseries"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.63679,
#                 "longitude": -118.96491
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "3029 Chateau Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3029 Chateau Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609344200",
#             "display_phone": "(760) 934-4200",
#             "distance": 50873.632013725946
#         },
#         {
#             "id": "N2eqSo_1vpFcICQnZzq3hA",
#             "alias": "rocket-dog-gourmet-brats-and-brew-fresno",
#             "name": "Rocket Dog Gourmet Brats & Brew",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Ux2fP0RhzuXVdAWKgU3Vhw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/rocket-dog-gourmet-brats-and-brew-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1024,
#             "categories": [
#                 {
#                     "alias": "hotdog",
#                     "title": "Hot Dogs"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8088049482694,
#                 "longitude": -119.788546097112
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "88 E Shaw Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93710",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "88 E Shaw Ave",
#                     "Fresno, CA 93710"
#                 ]
#             },
#             "phone": "+15592838096",
#             "display_phone": "(559) 283-8096",
#             "distance": 66631.82021258549
#         },
#         {
#             "id": "aEbC9m5SZC09gfNR2UYWxQ",
#             "alias": "restaurant-at-convict-lake-mammoth-lakes",
#             "name": "Restaurant At Convict Lake",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-AyKfycmDfx6ZVzxYjRj1Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/restaurant-at-convict-lake-mammoth-lakes?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 248,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.5980082466189,
#                 "longitude": -118.849853239954
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "2000 Convict Lake Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2000 Convict Lake Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609343800",
#             "display_phone": "(760) 934-3800",
#             "distance": 54487.76722818949
#         },
#         {
#             "id": "byUUxQV1CSOqJ4aFklMVrA",
#             "alias": "yosemite-national-park-yosemite-national-park-11",
#             "name": "Yosemite National Park",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/cCgZvrU8qSWzcG0MGNXJAg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/yosemite-national-park-yosemite-national-park-11?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1274,
#             "categories": [
#                 {
#                     "alias": "parks",
#                     "title": "Parks"
#                 },
#                 {
#                     "alias": "campgrounds",
#                     "title": "Campgrounds"
#                 },
#                 {
#                     "alias": "hiking",
#                     "title": "Hiking"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.747525,
#                 "longitude": -119.585552
#             },
#             "transactions": [],
#             "location": {
#                 "address1": null,
#                 "address2": null,
#                 "address3": null,
#                 "city": "Yosemite National Park",
#                 "zip_code": "95389",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "Yosemite National Park, CA 95389"
#                 ]
#             },
#             "phone": "+12093720200",
#             "display_phone": "(209) 372-0200",
#             "distance": 58828.37667996651
#         },
#         {
#             "id": "UVW_GF1zGsKN8OBOTGQUGA",
#             "alias": "annesso-pizzeria-fresno-2",
#             "name": "Annesso Pizzeria",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/QjB-SHBhreQj7a8ZC723TA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/annesso-pizzeria-fresno-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 457,
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.85922376493786,
#                 "longitude": -119.7830944195512
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "8484 N Friant Rd",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "8484 N Friant Rd",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15599818995",
#             "display_phone": "(559) 981-8995",
#             "distance": 62104.566315205986
#         },
#         {
#             "id": "KGsOt2vpYCrAf5uLNb0BWQ",
#             "alias": "the-warming-hut-mammoth-lakes-2",
#             "name": "The Warming Hut",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/LGqkGxms5nity1rbkbbzFw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-warming-hut-mammoth-lakes-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 671,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "comfortfood",
#                     "title": "Comfort Food"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.6411,
#                 "longitude": -118.96619
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "343 Old Mammoth Rd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "343 Old Mammoth Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609650549",
#             "display_phone": "(760) 965-0549",
#             "distance": 51229.543064896505
#         },
#         {
#             "id": "kVEGnADQh8_PZ481ZefN7A",
#             "alias": "pismos-coastal-grill-fresno",
#             "name": "Pismo's Coastal Grill",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vGTlxr9EGBcjKLE5QDkQ1g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/pismos-coastal-grill-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1834,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.8514568756632,
#                 "longitude": -119.79364423772844
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "7937 N Blackstone Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "7937 N Blackstone Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15594399463",
#             "display_phone": "(559) 439-9463",
#             "distance": 63376.24494309736
#         },
#         {
#             "id": "SZBLnPaU1tYUbixG5IYvlQ",
#             "alias": "carrillos-mexican-food-clovis",
#             "name": "Carrillo's Mexican Food",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/GxsN-hmqA9efLQCmiMeNuA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/carrillos-mexican-food-clovis?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 690,
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8234714433902,
#                 "longitude": -119.712107665837
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "151 W Bullard Ave",
#                 "address2": "Ste 101",
#                 "address3": null,
#                 "city": "Clovis",
#                 "zip_code": "93612",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "151 W Bullard Ave",
#                     "Ste 101",
#                     "Clovis, CA 93612"
#                 ]
#             },
#             "phone": "+15593255688",
#             "display_phone": "(559) 325-5688",
#             "distance": 61155.33560006727
#         },
#         {
#             "id": "XMH4GDn3pBeLMGpvaxCa6w",
#             "alias": "ararat-market-clovis",
#             "name": "Ararat Market",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/SC3AejhfiMVMbR8lcU8dNg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/ararat-market-clovis?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 357,
#             "categories": [
#                 {
#                     "alias": "armenian",
#                     "title": "Armenian"
#                 },
#                 {
#                     "alias": "mediterranean",
#                     "title": "Mediterranean"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 36.83899,
#                 "longitude": -119.69936
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$",
#             "location": {
#                 "address1": "497 N Clovis Ave",
#                 "address2": "Ste 205",
#                 "address3": "",
#                 "city": "Clovis",
#                 "zip_code": "93611",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "497 N Clovis Ave",
#                     "Ste 205",
#                     "Clovis, CA 93611"
#                 ]
#             },
#             "phone": "+15593249999",
#             "display_phone": "(559) 324-9999",
#             "distance": 59084.2180221019
#         },
#         {
#             "id": "TgGh-PaV-umsXvlkLiDuwQ",
#             "alias": "trelio-food-and-wine-clovis",
#             "name": "Trelio Food & Wine",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/j3uPktc5LQtezASWkHM47g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/trelio-food-and-wine-clovis?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 348,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.82446,
#                 "longitude": -119.70097
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "438 Clovis Ave",
#                 "address2": "Ste 4",
#                 "address3": "",
#                 "city": "Clovis",
#                 "zip_code": "93612",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "438 Clovis Ave",
#                     "Ste 4",
#                     "Clovis, CA 93612"
#                 ]
#             },
#             "phone": "+15592970783",
#             "display_phone": "(559) 297-0783",
#             "distance": 60488.91395362079
#         },
#         {
#             "id": "VVhUbg_F3RHzcQTl0fJ99w",
#             "alias": "phoenician-garden-mediterranean-bar-and-grill-fresno-2",
#             "name": "Phoenician Garden Mediterranean Bar and Grill",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/wAW_8SuLkyNjjd-kZ5Cwzw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/phoenician-garden-mediterranean-bar-and-grill-fresno-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 887,
#             "categories": [
#                 {
#                     "alias": "mediterranean",
#                     "title": "Mediterranean"
#                 },
#                 {
#                     "alias": "greek",
#                     "title": "Greek"
#                 },
#                 {
#                     "alias": "lebanese",
#                     "title": "Lebanese"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8364051687303,
#                 "longitude": -119.771824773016
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "1025 E Herndon Ave",
#                 "address2": "Ste 106",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1025 E Herndon Ave",
#                     "Ste 106",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15592612747",
#             "display_phone": "(559) 261-2747",
#             "distance": 63328.41900813897
#         },
#         {
#             "id": "A_7HXAZmYEEQDe8mk27urA",
#             "alias": "oakhurst-grill-and-whiskey-41-lounge-oakhurst",
#             "name": "Oakhurst Grill and Whiskey 41 Lounge",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/T5jXXUmKjniD-8gdS03V9A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/oakhurst-grill-and-whiskey-41-lounge-oakhurst?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 330,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.33603980916658,
#                 "longitude": -119.646133705974
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "40530 Hwy 41",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Oakhurst",
#                 "zip_code": "93644",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "40530 Hwy 41",
#                     "Oakhurst, CA 93644"
#                 ]
#             },
#             "phone": "+15596412477",
#             "display_phone": "(559) 641-2477",
#             "distance": 31091.779982034124
#         },
#         {
#             "id": "lBxTq2aoxMh1X7XrHUj7ZQ",
#             "alias": "se\u00f1or-aj\u00ed-peruvian-kitchen-fresno-2",
#             "name": "Se\u00f1or Aj\u00ed Peruvian Kitchen",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/FV-Dxd-2yhPuQeX0Qqlw0g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/se%C3%B1or-aj%C3%AD-peruvian-kitchen-fresno-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 375,
#             "categories": [
#                 {
#                     "alias": "latin",
#                     "title": "Latin American"
#                 },
#                 {
#                     "alias": "peruvian",
#                     "title": "Peruvian"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.83482,
#                 "longitude": -119.87954
#             },
#             "transactions": [
# ...
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "587 Old Mammoth Rd",
#                     "Ste 10",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609343902",
#             "display_phone": "(760) 934-3902",
#             "distance": 50911.48321879053
#         },
#         {
#             "id": "-8_Vm8hg9gi2gRD3UpnrOg",
#             "alias": "school-house-restaurant-and-tavern-sanger-3",
#             "name": "School House Restaurant & Tavern",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/xB0Ubhe0YwFeVuMleTTPtg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/school-house-restaurant-and-tavern-sanger-3?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 572,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.71935,
#                 "longitude": -119.44788
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1018 S Frankwood Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Sanger",
#                 "zip_code": "93657",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1018 S Frankwood Ave",
#                     "Sanger, CA 93657"
#                 ]
#             },
#             "phone": "+15597873271",
#             "display_phone": "(559) 787-3271",
#             "distance": 62202.88695382637
#         },
#         {
#             "id": "dwxU9Nke7wr3RZze0ivkTg",
#             "alias": "yosemite-ranch-fresno-5",
#             "name": "Yosemite Ranch",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/FT0ZsTBD4uaAFZv0_bLLLA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/yosemite-ranch-fresno-5?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 1123,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.86698,
#                 "longitude": -119.75625
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1520 E Champlain Dr",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1520 E Champlain Dr",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15594344403",
#             "display_phone": "(559) 434-4403",
#             "distance": 59866.69132309814
#         },
#         {
#             "id": "PGUM86R57lXPi4LFHJWhAg",
#             "alias": "dish-bistro-mammoth-lakes-2",
#             "name": "Dish Bistro",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/LsYY8ZKxqOli17yOJZ4d1w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/dish-bistro-mammoth-lakes-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 172,
#             "categories": [
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 },
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 37.63753,
#                 "longitude": -118.966839
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "588 Old Mammoth Rd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "588 Old Mammoth Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609203738",
#             "display_phone": "(760) 920-3738",
#             "distance": 50858.537843962964
#         },
#         {
#             "id": "XdTyuEoZLq4U3GXR7-HdIg",
#             "alias": "l-aperitif-bistro-fusion-fresno",
#             "name": "L'Aperitif Bistro Fusion",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/kUGl_dQslUFK3hQjXhYl7g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/l-aperitif-bistro-fusion-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 265,
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.834793,
#                 "longitude": -119.753049
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "location": {
#                 "address1": "6650 N Cedar Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93710",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "6650 N Cedar Ave",
#                     "Fresno, CA 93710"
#                 ]
#             },
#             "phone": "+15594723824",
#             "display_phone": "(559) 472-3824",
#             "distance": 62383.95648135885
#         },
#         {
#             "id": "3uBgSXc_FP1sRSKfjWExoQ",
#             "alias": "the-curry-pizza-company-fresno",
#             "name": "The Curry Pizza Company",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/kBhyBNN6D9IMIOyMezLGWw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-curry-pizza-company-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 555,
#             "categories": [
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "vegetarian",
#                     "title": "Vegetarian"
#                 },
#                 {
#                     "alias": "indpak",
#                     "title": "Indian"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.80812,
#                 "longitude": -119.84822
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "3173 W Shaw Ave",
#                 "address2": "Ste 103",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3173 W Shaw Ave",
#                     "Ste 103",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15593657000",
#             "display_phone": "(559) 365-7000",
#             "distance": 70235.46262196572
#         },
#         {
#             "id": "gsJYTks9w2BQOsZnJNFnwA",
#             "alias": "austria-hof-restaurant-mammoth-lakes",
#             "name": "Austria Hof Restaurant",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Zh660YZWUDF37En7FZ_kMQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/austria-hof-restaurant-mammoth-lakes?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 411,
#             "categories": [
#                 {
#                     "alias": "german",
#                     "title": "German"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.647592,
#                 "longitude": -119.000261
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "924 Canyon Blvd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "924 Canyon Blvd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609342764",
#             "display_phone": "(760) 934-2764",
#             "distance": 50122.66527259276
#         },
#         {
#             "id": "xK0_HYqEt30p80S84waDbA",
#             "alias": "starving-artists-bistro-fresno",
#             "name": "Starving Artists Bistro",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/hzKjox5_EVmFOUUnReYB5Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/starving-artists-bistro-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 552,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.8740930467465,
#                 "longitude": -119.777982
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "9447 N Fort Washington Rd",
#                 "address2": "Ste 101",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93730",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "9447 N Fort Washington Rd",
#                     "Ste 101",
#                     "Fresno, CA 93730"
#                 ]
#             },
#             "phone": "+15594330133",
#             "display_phone": "(559) 433-0133",
#             "distance": 60588.98005426178
#         },
#         {
#             "id": "M6qUGNq8_25RUs8Q9KcLaQ",
#             "alias": "duceys-on-the-lake-bass-lake-2",
#             "name": "Ducey's on the Lake",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/ht5jtZwkBNxPV0ryJLWTkA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/duceys-on-the-lake-bass-lake-2?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 583,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.3189103,
#                 "longitude": -119.5570908
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "39255 Marina Dr",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Bass Lake",
#                 "zip_code": "93604",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "39255 Marina Dr",
#                     "Bass Lake, CA 93604"
#                 ]
#             },
#             "phone": "+15596423131",
#             "display_phone": "(559) 642-3131",
#             "distance": 22996.202755920232
#         },
#         {
#             "id": "a3mxzNSSW11qjYLFjEbMGA",
#             "alias": "rio-acai-bowls-downtown-fresno-fresno",
#             "name": "Rio Acai Bowls - Downtown Fresno",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/jQjZuqPZg1l7a9QMDG4buA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/rio-acai-bowls-downtown-fresno-fresno?adjust_creative=u3n3MxneEKgTNb32qpsQBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=u3n3MxneEKgTNb32qpsQBA",
#             "review_count": 373,
#             "categories": [
#                 {
#                     "alias": "acaibowls",
#                     "title": "Acai Bowls"
#                 },
#                 {
#                     "alias": "poke",
#                     "title": "Poke"
#                 },
#                 {
#                     "alias": "vegan",
#                     "title": "Vegan"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.74292,
#                 "longitude": -119.80036
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$",
#             "location": {
#                 "address1": "1915 Fulton St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93721",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1915 Fulton St",
#                     "Fresno, CA 93721"
#                 ]
#             },
#             "phone": "+15594127725",
#             "display_phone": "(559) 412-7725",
#             "distance": 73026.6289524299
#         }
#     ],
#     "total": 3200,
#     "region": {
#         "center": {
#             "longitude": -119.3060302734375,
#             "latitude": 37.26682643661537
#         }
#     }
# }

# %%
df = pd.DataFrame(restaurants)
df
# Out:
#                         id                                              alias  \
# 0   9ZURLR_1ys3lN3Li8E_C0w                                  heirloom-fresno-2
# 1   xiPYoKcZ-QacPjrvUFRkpQ                         the-annex-kitchen-fresno-2
# 2   _9aI8_nUwnBTSlPEbWNdHw                                    mochuelo-fresno
# 3   _Ae3d3r7Ut-VAUoBcFYs7Q                                      saizon-fresno
# 4   SUrXfIWTrfwbQB4UD98-0w                               the-lime-lite-fresno
# 5   Sfpb-erwFWTp_HJ3kNRYWA                        coltons-social-house-clovis
# 6   0agq0wMl5TAyH4fSxN8NUA                              skadi-mammoth-lakes-2
# 7   GPP5E-f1dzAN08jNogYCjw                             smokehouse-41-oakhurst
# 8   jGBBu6ppRzyPjerTLr_PaQ                 sabor-cocina-latina-and-bar-fresno
# 9   Y58wkqUQ_-Kz8_o8qnP15A               charles-street-dinner-house-mariposa
# 10  ivx1E6-pW2TjxSG89fQagw                              red-apple-cafe-fresno
# 11  gwANdrsPZr3ZVAqN52vwqg                    the-elderberry-house-oakhurst-2
# 12  Ollnz3tVka1bMFbryAnn0g                                  hino-oishi-fresno
# 13  Oe2yeFzamknh4NvRBoJWlw                            13-prime-steak-clovis-3
# 14  dCAnqtdMqbvZXIJt2FA22g                 the-mogul-restaurant-mammoth-lakes
# 15  Vp4h70Ok9RYj8lAAUOfqAQ                        batter-up-pancakes-fresno-2
# 16  WlJqfuAfu9Mo3E-tZznsKw             mammoth-rock-brasserie-mammoth-lakes-2
# 17  N2eqSo_1vpFcICQnZzq3hA           rocket-dog-gourmet-brats-and-brew-fresno
# 18  aEbC9m5SZC09gfNR2UYWxQ           restaurant-at-convict-lake-mammoth-lakes
# 19  byUUxQV1CSOqJ4aFklMVrA   yosemite-national-park-yosemite-national-park-11
# 20  UVW_GF1zGsKN8OBOTGQUGA                          annesso-pizzeria-fresno-2
# 21  KGsOt2vpYCrAf5uLNb0BWQ                    the-warming-hut-mammoth-lakes-2
# 22  kVEGnADQh8_PZ481ZefN7A                        pismos-coastal-grill-fresno
# 23  SZBLnPaU1tYUbixG5IYvlQ                      carrillos-mexican-food-clovis
# 24  XMH4GDn3pBeLMGpvaxCa6w                               ararat-market-clovis
# 25  TgGh-PaV-umsXvlkLiDuwQ                        trelio-food-and-wine-clovis
# 26  VVhUbg_F3RHzcQTl0fJ99w  phoenician-garden-mediterranean-bar-and-grill-...
# 27  A_7HXAZmYEEQDe8mk27urA      oakhurst-grill-and-whiskey-41-lounge-oakhurst
# 28  lBxTq2aoxMh1X7XrHUj7ZQ                señor-ají-peruvian-kitchen-fresno-2
# 29  SOY2XbQxIH4yCQPjHcVqwg                               house-of-juju-clovis
# 30  -L-K_6JEexfqTYwbvC4Ihw           the-lakefront-restaurant-mammoth-lakes-3
# 31  hgZUMSrhohHkGKeCEiiy-A              south-gate-brewing-company-oakhurst-4
# 32  R6oihvAsESoP_77RcErBgA                           the-craft-house-clovis-4
# 33  tqo1WOpnT2nZQUJSUAIAFA                    vintage-steakhouse-coarsegold-2
# 34  It0iQE9-kR4KkTh4dL-Xcw                                    namikaze-fresno
# 35  zax7GbinnYMWMtgW9gdZQg                     cracked-pepper-bistro-fresno-2
# 36  8rmEBlB0_qBSy0P3u-kWjw                      wild-fig-kitchen-coarsegold-5
# 37  j1Zoqb_mNnrliL-Xp6_Klg                                  lazy-dog-fresno-3
# 38  gXis25p88klWtI6b3Ua6Nw          tah-deeg-authentic-persian-cuisine-clovis
# 39  VvPOfhbH6BH3I-vFG1hALQ                               ramen-hayashi-clovis
# 40  w_MtMINViH2_cfUUkWPPZw                       mammoth-tavern-mammoth-lakes
# 41  -8_Vm8hg9gi2gRD3UpnrOg        school-house-restaurant-and-tavern-sanger-3
# 42  dwxU9Nke7wr3RZze0ivkTg                            yosemite-ranch-fresno-5
# 43  PGUM86R57lXPi4LFHJWhAg                        dish-bistro-mammoth-lakes-2
# 44  XdTyuEoZLq4U3GXR7-HdIg                    l-aperitif-bistro-fusion-fresno
# 45  3uBgSXc_FP1sRSKfjWExoQ                     the-curry-pizza-company-fresno
# 46  gsJYTks9w2BQOsZnJNFnwA               austria-hof-restaurant-mammoth-lakes
# 47  xK0_HYqEt30p80S84waDbA                     starving-artists-bistro-fresno
# 48  M6qUGNq8_25RUs8Q9KcLaQ                     duceys-on-the-lake-bass-lake-2
# 49  a3mxzNSSW11qjYLFjEbMGA              rio-acai-bowls-downtown-fresno-fresno
#
#                                              name  \
# 0                                        Heirloom
# 1                               The Annex Kitchen
# 2                                        Mochuelo
# 3                                          Saizon
# 4                                   The Lime Lite
# 5                           Colton's Social House
# 6                                           SKADI
# 7                                   Smokehouse 41
# 8                       Sabor Cocina Latina & Bar
# 9                     Charles Street Dinner House
# 10                                 Red Apple Cafe
# 11                           The Elderberry House
# 12                                     Hino Oishi
# 13                                 13 Prime Steak
# 14                           The Mogul Restaurant
# 15                             Batter Up Pancakes
# 16                         Mammoth Rock Brasserie
# 17                Rocket Dog Gourmet Brats & Brew
# 18                     Restaurant At Convict Lake
# 19                         Yosemite National Park
# 20                               Annesso Pizzeria
# 21                                The Warming Hut
# 22                          Pismo's Coastal Grill
# 23                        Carrillo's Mexican Food
# 24                                  Ararat Market
# 25                             Trelio Food & Wine
# 26  Phoenician Garden Mediterranean Bar and Grill
# 27           Oakhurst Grill and Whiskey 41 Lounge
# 28                     Señor Ají Peruvian Kitchen
# 29                                  House of JuJu
# 30                       The Lakefront Restaurant
# 31                     South Gate Brewing Company
# 32                                The Craft House
# 33                             Vintage Steakhouse
# 34                                       Namikaze
# 35                          Cracked Pepper Bistro
# 36                               Wild Fig Kitchen
# 37                                       Lazy Dog
# 38             Tah Deeg Authentic Persian Cuisine
# 39                                  Ramen Hayashi
# 40                                 Mammoth Tavern
# 41               School House Restaurant & Tavern
# 42                                 Yosemite Ranch
# 43                                    Dish Bistro
# 44                       L'Aperitif Bistro Fusion
# 45                        The Curry Pizza Company
# 46                         Austria Hof Restaurant
# 47                        Starving Artists Bistro
# 48                            Ducey's on the Lake
# 49               Rio Acai Bowls - Downtown Fresno
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/7fjE8h...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/Y-UPgy...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/7JWSi-...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/K7CSA_...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/N4-t5R...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/ENIJsw...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/f9dDgh...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/HcfpJd...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/EeGd4s...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/CfDdO0...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/vauGir...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/NkGEpj...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/TmbE4r...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/gfoazh...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/gGjl6h...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/JOl3Ab...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/wT3rBm...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/Ux2fP0...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/-AyKfy...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/cCgZvr...      False
# 20  https://s3-media3.fl.yelpcdn.com/bphoto/QjB-SH...      False
# 21  https://s3-media2.fl.yelpcdn.com/bphoto/LGqkGx...      False
# 22  https://s3-media1.fl.yelpcdn.com/bphoto/vGTlxr...      False
# 23  https://s3-media3.fl.yelpcdn.com/bphoto/GxsN-h...      False
# 24  https://s3-media2.fl.yelpcdn.com/bphoto/SC3Aej...      False
# 25  https://s3-media1.fl.yelpcdn.com/bphoto/j3uPkt...      False
# 26  https://s3-media2.fl.yelpcdn.com/bphoto/wAW_8S...      False
# 27  https://s3-media2.fl.yelpcdn.com/bphoto/T5jXXU...      False
# 28  https://s3-media1.fl.yelpcdn.com/bphoto/FV-Dxd...      False
# 29  https://s3-media4.fl.yelpcdn.com/bphoto/ctCDnh...      False
# 30  https://s3-media3.fl.yelpcdn.com/bphoto/wJiNWy...      False
# 31  https://s3-media1.fl.yelpcdn.com/bphoto/8HtTXc...      False
# 32  https://s3-media3.fl.yelpcdn.com/bphoto/9sfnt5...      False
# 33  https://s3-media4.fl.yelpcdn.com/bphoto/Jm-gcN...      False
# 34  https://s3-media2.fl.yelpcdn.com/bphoto/wQ2P5K...      False
# 35  https://s3-media4.fl.yelpcdn.com/bphoto/k-gX8F...      False
# 36  https://s3-media3.fl.yelpcdn.com/bphoto/rreQvP...      False
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/tTTVFl...      False
# 38  https://s3-media1.fl.yelpcdn.com/bphoto/5J7MyE...      False
# 39  https://s3-media2.fl.yelpcdn.com/bphoto/LI8uic...      False
# 40  https://s3-media2.fl.yelpcdn.com/bphoto/Jv0UTF...      False
# 41  https://s3-media2.fl.yelpcdn.com/bphoto/xB0Ubh...      False
# 42  https://s3-media3.fl.yelpcdn.com/bphoto/FT0ZsT...      False
# 43  https://s3-media2.fl.yelpcdn.com/bphoto/LsYY8Z...      False
# 44  https://s3-media2.fl.yelpcdn.com/bphoto/kUGl_d...      False
# 45  https://s3-media4.fl.yelpcdn.com/bphoto/kBhyBN...      False
# 46  https://s3-media1.fl.yelpcdn.com/bphoto/Zh660Y...      False
# 47  https://s3-media4.fl.yelpcdn.com/bphoto/hzKjox...      False
# 48  https://s3-media2.fl.yelpcdn.com/bphoto/ht5jtZ...      False
# 49  https://s3-media3.fl.yelpcdn.com/bphoto/jQjZuq...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/heirloom-fresno-2?adj...          1976
# 1   https://www.yelp.com/biz/the-annex-kitchen-fre...          1529
# 2   https://www.yelp.com/biz/mochuelo-fresno?adjus...           391
# 3   https://www.yelp.com/biz/saizon-fresno?adjust_...           323
# 4   https://www.yelp.com/biz/the-lime-lite-fresno?...           468
# 5   https://www.yelp.com/biz/coltons-social-house-...          1529
# 6   https://www.yelp.com/biz/skadi-mammoth-lakes-2...           422
# 7   https://www.yelp.com/biz/smokehouse-41-oakhurs...           721
# 8   https://www.yelp.com/biz/sabor-cocina-latina-a...           347
# 9   https://www.yelp.com/biz/charles-street-dinner...           549
# 10  https://www.yelp.com/biz/red-apple-cafe-fresno...          1287
# 11  https://www.yelp.com/biz/the-elderberry-house-...           283
# 12  https://www.yelp.com/biz/hino-oishi-fresno?adj...          1078
# 13  https://www.yelp.com/biz/13-prime-steak-clovis...           431
# 14  https://www.yelp.com/biz/the-mogul-restaurant-...           609
# 15  https://www.yelp.com/biz/batter-up-pancakes-fr...          1420
# 16  https://www.yelp.com/biz/mammoth-rock-brasseri...           405
# 17  https://www.yelp.com/biz/rocket-dog-gourmet-br...          1024
# 18  https://www.yelp.com/biz/restaurant-at-convict...           248
# 19  https://www.yelp.com/biz/yosemite-national-par...          1274
# 20  https://www.yelp.com/biz/annesso-pizzeria-fres...           457
# 21  https://www.yelp.com/biz/the-warming-hut-mammo...           671
# 22  https://www.yelp.com/biz/pismos-coastal-grill-...          1834
# 23  https://www.yelp.com/biz/carrillos-mexican-foo...           690
# 24  https://www.yelp.com/biz/ararat-market-clovis?...           357
# 25  https://www.yelp.com/biz/trelio-food-and-wine-...           348
# 26  https://www.yelp.com/biz/phoenician-garden-med...           887
# 27  https://www.yelp.com/biz/oakhurst-grill-and-wh...           330
# 28  https://www.yelp.com/biz/se%C3%B1or-aj%C3%AD-p...           375
# 29  https://www.yelp.com/biz/house-of-juju-clovis?...          1428
# 30  https://www.yelp.com/biz/the-lakefront-restaur...           352
# 31  https://www.yelp.com/biz/south-gate-brewing-co...          1495
# 32  https://www.yelp.com/biz/the-craft-house-clovi...           715
# 33  https://www.yelp.com/biz/vintage-steakhouse-co...           102
# 34  https://www.yelp.com/biz/namikaze-fresno?adjus...           497
# 35  https://www.yelp.com/biz/cracked-pepper-bistro...           537
# 36  https://www.yelp.com/biz/wild-fig-kitchen-coar...           381
# 37  https://www.yelp.com/biz/lazy-dog-fresno-3?adj...          1200
# 38  https://www.yelp.com/biz/tah-deeg-authentic-pe...           234
# 39  https://www.yelp.com/biz/ramen-hayashi-clovis?...           507
# 40  https://www.yelp.com/biz/mammoth-tavern-mammot...           532
# 41  https://www.yelp.com/biz/school-house-restaura...           572
# 42  https://www.yelp.com/biz/yosemite-ranch-fresno...          1123
# 43  https://www.yelp.com/biz/dish-bistro-mammoth-l...           172
# 44  https://www.yelp.com/biz/l-aperitif-bistro-fus...           265
# 45  https://www.yelp.com/biz/the-curry-pizza-compa...           555
# 46  https://www.yelp.com/biz/austria-hof-restauran...           411
# 47  https://www.yelp.com/biz/starving-artists-bist...           552
# 48  https://www.yelp.com/biz/duceys-on-the-lake-ba...           583
# 49  https://www.yelp.com/biz/rio-acai-bowls-downto...           373
#
#                                            categories  rating  \
# 0   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2   [{'alias': 'tapasmallplates', 'title': 'Tapas/...     4.5
# 3   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 4   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 5   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 6   [{'alias': 'modern_european', 'title': 'Modern...     5.0
# 7   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 8   [{'alias': 'latin', 'title': 'Latin American'}...     4.5
# 9   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 10  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 11  [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 12  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 13  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 14  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 15       [{'alias': 'pancakes', 'title': 'Pancakes'}]     4.5
# 16  [{'alias': 'brasseries', 'title': 'Brasseries'...     4.5
# 17  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...     4.5
# 18  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 19  [{'alias': 'parks', 'title': 'Parks'}, {'alias...     4.5
# 20  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 21  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 22  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 23         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 24  [{'alias': 'armenian', 'title': 'Armenian'}, {...     5.0
# 25  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 26  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 27  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 28  [{'alias': 'latin', 'title': 'Latin American'}...     4.5
# 29  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 30  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 31  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 32  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.5
# 33  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 34  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 35  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 36  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 37  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 38  [{'alias': 'persian', 'title': 'Persian/Irania...     4.5
# 39             [{'alias': 'ramen', 'title': 'Ramen'}]     4.5
# 40  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 41  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 42  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 43  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     5.0
# 44  [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 45  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 46  [{'alias': 'german', 'title': 'German'}, {'ali...     4.0
# 47  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 48  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 49  [{'alias': 'acaibowls', 'title': 'Acai Bowls'}...     4.5
#
#                                           coordinates  \
# 0   {'latitude': 36.85648251011611, 'longitude': -...
# 1     {'latitude': 36.80758, 'longitude': -119.83229}
# 2   {'latitude': 36.807753, 'longitude': -119.833184}
# 3   {'latitude': 36.86728041008362, 'longitude': -...
# 4   {'latitude': 36.808791, 'longitude': -119.809706}
# 5     {'latitude': 36.80802, 'longitude': -119.69427}
# 6       {'latitude': 37.6512, 'longitude': -118.9829}
# 7     {'latitude': 37.33914, 'longitude': -119.64334}
# 8   {'latitude': 36.851711, 'longitude': -119.806469}
# 9   {'latitude': 37.48545467039154, 'longitude': -...
# 10  {'latitude': 36.837659, 'longitude': -119.801605}
# 11  {'latitude': 37.327100397143525, 'longitude': ...
# 12  {'latitude': 36.8116445316553, 'longitude': -1...
# 13    {'latitude': 36.85358, 'longitude': -119.72805}
# 14    {'latitude': 37.64519, 'longitude': -118.96671}
# 15  {'latitude': 36.8525455, 'longitude': -119.758...
# 16    {'latitude': 37.63679, 'longitude': -118.96491}
# 17  {'latitude': 36.8088049482694, 'longitude': -1...
# 18  {'latitude': 37.5980082466189, 'longitude': -1...
# 19  {'latitude': 37.747525, 'longitude': -119.585552}
# 20  {'latitude': 36.85922376493786, 'longitude': -...
# 21     {'latitude': 37.6411, 'longitude': -118.96619}
# 22  {'latitude': 36.8514568756632, 'longitude': -1...
# 23  {'latitude': 36.8234714433902, 'longitude': -1...
# 24    {'latitude': 36.83899, 'longitude': -119.69936}
# 25    {'latitude': 36.82446, 'longitude': -119.70097}
# 26  {'latitude': 36.8364051687303, 'longitude': -1...
# 27  {'latitude': 37.33603980916658, 'longitude': -...
# 28    {'latitude': 36.83482, 'longitude': -119.87954}
# 29  {'latitude': 36.823308, 'longitude': -119.701834}
# 30  {'latitude': 37.6198509204488, 'longitude': -1...
# 31  {'latitude': 37.3331104, 'longitude': -119.660...
# 32  {'latitude': 36.8209001, 'longitude': -119.702...
# 33  {'latitude': 37.2120254, 'longitude': -119.699...
# 34  {'latitude': 36.872349, 'longitude': -119.7626...
# 35  {'latitude': 36.8355750271176, 'longitude': -1...
# 36  {'latitude': 37.2622980132899, 'longitude': -1...
# 37    {'latitude': 36.85118, 'longitude': -119.79151}
# 38  {'latitude': 36.807037, 'longitude': -119.692677}
# 39  {'latitude': 36.83788190993908, 'longitude': -...
# 40  {'latitude': 37.6375741580282, 'longitude': -1...
# 41    {'latitude': 36.71935, 'longitude': -119.44788}
# 42    {'latitude': 36.86698, 'longitude': -119.75625}
# 43   {'latitude': 37.63753, 'longitude': -118.966839}
# 44  {'latitude': 36.834793, 'longitude': -119.753049}
# 45    {'latitude': 36.80812, 'longitude': -119.84822}
# 46  {'latitude': 37.647592, 'longitude': -119.000261}
# 47  {'latitude': 36.8740930467465, 'longitude': -1...
# 48  {'latitude': 37.3189103, 'longitude': -119.557...
# 49    {'latitude': 36.74292, 'longitude': -119.80036}
#
#                                   transactions price  \
# 0                                   [delivery]    $$
# 1                                   [delivery]   $$$
# 2   [delivery, pickup, restaurant_reservation]    $$
# 3                                           []   $$$
# 4                                   [delivery]   $$$
# 5   [delivery, pickup, restaurant_reservation]    $$
# 6                                           []  $$$$
# 7                                           []    $$
# 8                                   [delivery]    $$
# 9                                           []    $$
# 10                                  [delivery]    $$
# 11                                          []  $$$$
# 12                                  [delivery]    $$
# 13                                  [delivery]   $$$
# 14                                          []   $$$
# 15                          [delivery, pickup]    $$
# 16                                          []   $$$
# 17                          [delivery, pickup]    $$
# 18                                          []   $$$
# 19                                          []   NaN
# 20                                          []    $$
# 21                                          []    $$
# 22  [delivery, pickup, restaurant_reservation]    $$
# 23                                  [delivery]    $$
# 24                                  [delivery]     $
# 25                          [delivery, pickup]   $$$
# 26                          [delivery, pickup]    $$
# 27                                          []    $$
# 28                          [delivery, pickup]    $$
# 29                                  [delivery]    $$
# 30                                          []  $$$$
# 31                                          []    $$
# 32                          [delivery, pickup]    $$
# 33                                          []   $$$
# 34                          [delivery, pickup]    $$
# 35                                          []   $$$
# 36                                          []    $$
# 37                          [delivery, pickup]    $$
# 38                          [delivery, pickup]    $$
# 39                          [delivery, pickup]    $$
# 40                                          []    $$
# 41                                          []    $$
# 42  [delivery, pickup, restaurant_reservation]   $$$
# 43                                          []    $$
# 44                    [restaurant_reservation]   NaN
# 45                          [delivery, pickup]    $$
# 46                    [restaurant_reservation]    $$
# 47                                          []    $$
# 48                                          []    $$
# 49                          [delivery, pickup]     $
#
#                                              location         phone  \
# 0   {'address1': '8398 N Fresno St', 'address2': '...  +15592289735
# 1   {'address1': '2257 W Shaw Ave', 'address2': ''...  +15592488512
# 2   {'address1': '2305 W Shaw Ave', 'address2': ''...  +15593485555
# 3   {'address1': '2894 E Shepherd Ave', 'address2'...  +15595529688
# 4   {'address1': '1054 W Shaw Ave', 'address2': ''...  +15592241054
# 5   {'address1': '1150 Shaw Ave', 'address2': '', ...  +15597216655
# 6   {'address1': '94 Berner St', 'address2': 'Ste ...  +17609140962
# 7   {'address1': '40713 Hwy 41', 'address2': '', '...  +15596422271
# 8   {'address1': '7845 N Palm Ave', 'address2': 'S...  +15593751644
# 9   {'address1': '5043 Hwy 140 and 7th St', 'addre...  +12099662366
# 10  {'address1': '488 W Herndon Ave', 'address2': ...  +15592611505
# 11  {'address1': '48688 Victoria Ln', 'address2': ...  +15596836800
# 12  {'address1': '3091 E Campus Pointe Dr', 'addre...  +15597654657
# 13  {'address1': '1345 N Willow Ave', 'address2': ...  +15592161313
# 14  {'address1': '1528 Tavern Rd', 'address2': '',...  +17609343039
# 15  {'address1': '8029 N Cedar Ave', 'address2': '...  +15594401221
# 16  {'address1': '3029 Chateau Rd', 'address2': ''...  +17609344200
# 17  {'address1': '88 E Shaw Ave', 'address2': None...  +15592838096
# 18  {'address1': '2000 Convict Lake Rd', 'address2...  +17609343800
# 19  {'address1': None, 'address2': None, 'address3...  +12093720200
# 20  {'address1': '8484 N Friant Rd', 'address2': '...  +15599818995
# 21  {'address1': '343 Old Mammoth Rd', 'address2':...  +17609650549
# 22  {'address1': '7937 N Blackstone Ave', 'address...  +15594399463
# 23  {'address1': '151 W Bullard Ave', 'address2': ...  +15593255688
# 24  {'address1': '497 N Clovis Ave', 'address2': '...  +15593249999
# 25  {'address1': '438 Clovis Ave', 'address2': 'St...  +15592970783
# 26  {'address1': '1025 E Herndon Ave', 'address2':...  +15592612747
# 27  {'address1': '40530 Hwy 41', 'address2': '', '...  +15596412477
# 28  {'address1': '6701 N Milburn Ave', 'address2':...  +15593751285
# 29  {'address1': '565 Pollasky Ave', 'address2': '...  +15592983090
# 30  {'address1': '163 Twin Lakes Rd', 'address2': ...  +17609147157
# 31  {'address1': '40233 Enterprise Dr', 'address2'...  +15596922739
# 32  {'address1': '760 Pollasky Ave', 'address2': N...  +15594723398
# 33  {'address1': '711 Lucky Ln', 'address2': '', '...  +15596925200
# 34  {'address1': '1134 E Champlain Dr', 'address2'...  +15594785917
# 35  {'address1': '6737 N Palm Ave', 'address2': ''...  +15592229119
# 36  {'address1': '35300 Hwy 41', 'address2': 'Ste ...  +15596583447
# 37  {'address1': '7965 N Blackstone Ave', 'address...  +15596915300
# 38  {'address1': '1250 Shaw Ave', 'address2': 'Ste...  +15593218442
# 39  {'address1': '1755 Herndon Ave', 'address2': N...  +15599406400
# 40  {'address1': '587 Old Mammoth Rd', 'address2':...  +17609343902
# 41  {'address1': '1018 S Frankwood Ave', 'address2...  +15597873271
# 42  {'address1': '1520 E Champlain Dr', 'address2'...  +15594344403
# 43  {'address1': '588 Old Mammoth Rd', 'address2':...  +17609203738
# 44  {'address1': '6650 N Cedar Ave', 'address2': N...  +15594723824
# 45  {'address1': '3173 W Shaw Ave', 'address2': 'S...  +15593657000
# 46  {'address1': '924 Canyon Blvd', 'address2': ''...  +17609342764
# 47  {'address1': '9447 N Fort Washington Rd', 'add...  +15594330133
# 48  {'address1': '39255 Marina Dr', 'address2': ''...  +15596423131
# 49  {'address1': '1915 Fulton St', 'address2': '',...  +15594127725
#
#      display_phone      distance
# 0   (559) 228-9735  62366.051097
# 1   (559) 248-8512  69284.527511
# 2   (559) 348-5555  69334.717455
# 3   (559) 552-9688  58327.867719
# 4   (559) 224-1054  67857.037542
# 5   (559) 721-6655  61663.219245
# 6   (760) 914-0962  51284.624899
# 7   (559) 642-2271  30971.077571
# 8   (559) 375-1644  64135.990019
# 9   (209) 966-2366  63215.823072
# 10  (559) 261-1505  64989.236683
# 11  (559) 683-6800  32143.065198
# 12  (559) 765-4657  63392.155031
# 13  (559) 216-1313  59356.546903
# 14  (760) 934-3039  51550.001168
# 15  (559) 440-1221  61177.632337
# 16  (760) 934-4200  50873.632014
# 17  (559) 283-8096  66631.820213
# 18  (760) 934-3800  54487.767228
# 19  (209) 372-0200  58828.376680
# 20  (559) 981-8995  62104.566315
# 21  (760) 965-0549  51229.543065
# 22  (559) 439-9463  63376.244943
# 23  (559) 325-5688  61155.335600
# 24  (559) 324-9999  59084.218022
# 25  (559) 297-0783  60488.913954
# 26  (559) 261-2747  63328.419008
# 27  (559) 641-2477  31091.779982
# 28  (559) 375-1285  70076.257935
# 29  (559) 298-3090  60636.419762
# 30  (760) 914-7157  47239.800794
# 31  (559) 692-2739  32232.471246
# 32  (559) 472-3398  60878.835563
# 33  (559) 692-5200  35434.283230
# 34  (559) 478-5917  59797.639172
# 35  (559) 222-9119  65691.845580
# 36  (559) 658-3447  34960.413265
# 37  (559) 691-5300  63272.268564
# 38  (559) 321-8442  61654.826051
# 39  (559) 940-6400  58457.765468
# 40  (760) 934-3902  50911.483219
# 41  (559) 787-3271  62202.886954
# 42  (559) 434-4403  59866.691323
# 43  (760) 920-3738  50858.537844
# 44  (559) 472-3824  62383.956481
# 45  (559) 365-7000  70235.462622
# 46  (760) 934-2764  50122.665273
# 47  (559) 433-0133  60588.980054
# 48  (559) 642-3131  22996.202756
# 49  (559) 412-7725  73026.628952

# %%
counts = df['id'].count()
counts
# Out:
# 50
