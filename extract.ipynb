# %%
import pandas as pd
import requests
import json

# %%
# Import API key
from api import API_key

# %%
url = "https://api.yelp.com/v3/businesses/search"

# %%
headers = {
        'Authorization': 'Bearer ' + API_key,
        'Content-Type': 'application/json'
    }

# %%
states = ['New York', 'California']
cusines = ['italian', 'mexican']
restaurants= []

# %%
for state in states:
    for cusine in cusines:
        params = {'location': state,
            'limit': 50,
            'categories': cusine
            }
        response = requests.get(url,  headers=headers, params=params).json()
    #print(json.dumps(response, indent=4, sort_keys=False))
        if 'businesses' in response:
            restaurants.extend(response['businesses'])

# %%
 # Pretty print JSON for all launchpads

# %%
df = pd.DataFrame(restaurants)
df
# Out:
#                         id                              alias  \
# 0   nRO136GRieGtxz18uD61DA       eleven-madison-park-new-york
# 1   16ZnHpuaaBt92XWeJHCC5A              olio-e-più-new-york-7
# 2   s3jou_L_LVYGkNHiuhjlew  boucherie-west-village-new-york-3
# 3   j1S3NUrkB3BVT49n_e76NQ     best-bagel-and-coffee-new-york
# 4   1DfbZ0VsSCg9g1KILmnvzQ                    per-se-new-york
# ..                     ...                                ...
# 95  PGUM86R57lXPi4LFHJWhAg        dish-bistro-mammoth-lakes-2
# 96  M6qUGNq8_25RUs8Q9KcLaQ     duceys-on-the-lake-bass-lake-2
# 97  XdTyuEoZLq4U3GXR7-HdIg    l-aperitif-bistro-fusion-fresno
# 98  3uBgSXc_FP1sRSKfjWExoQ     the-curry-pizza-company-fresno
# 99  MPbMQtWnaGXo01xVYhAq-g                       parma-fresno
#
#                         name  \
# 0        Eleven Madison Park
# 1                 Olio e Più
# 2     Boucherie West Village
# 3        Best Bagel & Coffee
# 4                     Per Se
# ..                       ...
# 95               Dish Bistro
# 96       Ducey's on the Lake
# 97  L'Aperitif Bistro Fusion
# 98   The Curry Pizza Company
# 99                     Parma
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/s_H7gm...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/WxNMDk...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/91RtGG...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/531LmZ...      False
# ..                                                ...        ...
# 95  https://s3-media2.fl.yelpcdn.com/bphoto/LsYY8Z...      False
# 96  https://s3-media2.fl.yelpcdn.com/bphoto/ht5jtZ...      False
# 97  https://s3-media2.fl.yelpcdn.com/bphoto/kUGl_d...      False
# 98  https://s3-media4.fl.yelpcdn.com/bphoto/kBhyBN...      False
# 99  https://s3-media2.fl.yelpcdn.com/bphoto/WhO7AR...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/eleven-madison-park-n...          2422
# 1   https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          4651
# 2   https://www.yelp.com/biz/boucherie-west-villag...          2253
# 3   https://www.yelp.com/biz/best-bagel-and-coffee...          4542
# 4   https://www.yelp.com/biz/per-se-new-york?adjus...          1871
# ..                                                ...           ...
# 95  https://www.yelp.com/biz/dish-bistro-mammoth-l...           172
# 96  https://www.yelp.com/biz/duceys-on-the-lake-ba...           583
# 97  https://www.yelp.com/biz/l-aperitif-bistro-fus...           265
# 98  https://www.yelp.com/biz/the-curry-pizza-compa...           555
# 99  https://www.yelp.com/biz/parma-fresno?adjust_c...           327
#
#                                            categories  rating  \
# 0   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2   [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 3   [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...     4.5
# 4            [{'alias': 'french', 'title': 'French'}]     4.5
# ..                                                ...     ...
# 95  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     5.0
# 96  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 97  [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 98  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 99  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
#
#                                           coordinates  \
# 0   {'latitude': 40.7416907417333, 'longitude': -7...
# 1   {'latitude': 40.733798036104304, 'longitude': ...
# 2   {'latitude': 40.733063, 'longitude': -74.0028772}
# 3   {'latitude': 40.7522683, 'longitude': -73.9910...
# 4   {'latitude': 40.7681528889558, 'longitude': -7...
# ..                                                ...
# 95   {'latitude': 37.63753, 'longitude': -118.966839}
# 96  {'latitude': 37.3189103, 'longitude': -119.557...
# 97  {'latitude': 36.834793, 'longitude': -119.753049}
# 98    {'latitude': 36.80812, 'longitude': -119.84822}
# 99  {'latitude': 36.83546, 'longitude': -119.8101351}
#
#                 transactions price  \
# 0                         []  $$$$
# 1         [delivery, pickup]    $$
# 2         [delivery, pickup]   $$$
# 3         [delivery, pickup]     $
# 4                         []  $$$$
# ..                       ...   ...
# 95                        []    $$
# 96                        []    $$
# 97  [restaurant_reservation]   NaN
# 98        [delivery, pickup]    $$
# 99        [delivery, pickup]   $$$
#
#                                              location         phone  \
# 0   {'address1': '11 Madison Ave', 'address2': '',...  +12128890905
# 1   {'address1': '3 Greenwich Ave', 'address2': No...  +12122436546
# 2   {'address1': '99 7th Ave S', 'address2': '', '...  +12128371616
# 3   {'address1': '225 W 35th St', 'address2': '', ...  +12125644409
# 4   {'address1': '10 Columbus Cir', 'address2': 'F...  +12128239335
# ..                                                ...           ...
# 95  {'address1': '588 Old Mammoth Rd', 'address2':...  +17609203738
# 96  {'address1': '39255 Marina Dr', 'address2': ''...  +15596423131
# 97  {'address1': '6650 N Cedar Ave', 'address2': N...  +15594723824
# 98  {'address1': '3173 W Shaw Ave', 'address2': 'S...  +15593657000
# 99  {'address1': '6729 N Palm Ave', 'address2': ''...  +15594323389
#
#      display_phone      distance
# 0   (212) 889-0905   3892.073001
# 1   (212) 243-6546   3434.912792
# 2   (212) 837-1616   3508.639836
# 3   (212) 564-4409   5108.979758
# 4   (212) 823-9335   6779.094813
# ..             ...           ...
# 95  (760) 920-3738  50858.537844
# 96  (559) 642-3131  22996.202756
# 97  (559) 472-3824  62383.956481
# 98  (559) 365-7000  70235.462622
# 99  (559) 432-3389  65678.165858
#
# [100 rows x 16 columns]

# %%
counts = df['id'].count()
counts
# Out:
# 100
