# %%
import pandas as pd
import requests
import json

# %%
# Import API key
from api import API_key

# %%
url = "https://api.yelp.com/v3/businesses/search"

# %%
headers = {
        'Authorization': 'Bearer ' + API_key,
        'Content-Type': 'application/json'
    }

# %%
states = ['New York', 'California']
cusines = ['italian', 'mexican']
restaurants= []

# %%
for state in states:
    for cusine in cusines:
        params = {'location': state,
            'limit': 50,
            'categories': cusine
            }
        response = requests.get(url,  headers=headers, params=params).json()
    #print(json.dumps(response, indent=4, sort_keys=False))
        if 'businesses' in response:
            restaurants.extend(response['businesses'])

# %%
df = pd.DataFrame(restaurants)
df
# Out:
#                          id                               alias  \
# 0    h37t9rA06Sr4EetJjKrfzw                  don-angie-new-york
# 1    WG639VkTjmK5dzydd1BBJA                 rubirosa-new-york-2
# 2    16ZnHpuaaBt92XWeJHCC5A               olio-e-più-new-york-7
# 3    zj8Lq1T8KIC5zwFief15jg      prince-street-pizza-new-york-2
# 4    MphfKkYFEe0BDQ6hZ0A5fA            gelso-and-grand-new-york
# ..                      ...                                 ...
# 195  LxOvO143OBeS1lfpv1awYQ            country-fare-cafe-fresno
# 196  H-EWbb1UahkuraZIIy2ifA                taco-machin-fresno-2
# 197  VLfUkbBnf3p3mpii_T7VlA  el-rinconcito-mexican-grill-madera
# 198  Ut255v3oDhp_wrvQttdEIQ                      garrafa-fresno
# 199  D-CAUCQLAFKYJMNP4sUQ6w                 cdt-cocina-fresno-2
#
#                             name  \
# 0                      Don Angie
# 1                       Rubirosa
# 2                     Olio e Più
# 3            Prince Street Pizza
# 4                  Gelso & Grand
# ..                           ...
# 195            Country Fare Cafe
# 196                  Taco Machin
# 197  El Rinconcito Mexican Grill
# 198                      Garrafa
# 199                   CDT Cocina
#
#                                              image_url  is_closed  \
# 0    https://s3-media2.fl.yelpcdn.com/bphoto/onJX6_...      False
# 1    https://s3-media3.fl.yelpcdn.com/bphoto/F65qqO...      False
# 2    https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 3    https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...      False
# 4    https://s3-media3.fl.yelpcdn.com/bphoto/ZV0bgS...      False
# ..                                                 ...        ...
# 195  https://s3-media2.fl.yelpcdn.com/bphoto/V341EW...      False
# 196  https://s3-media3.fl.yelpcdn.com/bphoto/laftHy...      False
# 197  https://s3-media3.fl.yelpcdn.com/bphoto/Vwd0mv...      False
# 198  https://s3-media3.fl.yelpcdn.com/bphoto/tSfNOJ...      False
# 199  https://s3-media3.fl.yelpcdn.com/bphoto/lUwLBD...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/don-angie-new-york?ad...           744
# 1    https://www.yelp.com/biz/rubirosa-new-york-2?a...          3090
# 2    https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          4655
# 3    https://www.yelp.com/biz/prince-street-pizza-n...          4983
# 4    https://www.yelp.com/biz/gelso-and-grand-new-y...          1423
# ..                                                 ...           ...
# 195  https://www.yelp.com/biz/country-fare-cafe-fre...           258
# 196  https://www.yelp.com/biz/taco-machin-fresno-2?...           133
# 197  https://www.yelp.com/biz/el-rinconcito-mexican...            60
# 198  https://www.yelp.com/biz/garrafa-fresno?adjust...            44
# 199  https://www.yelp.com/biz/cdt-cocina-fresno-2?a...            59
#
#                                             categories  rating  \
# 0    [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 1    [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 2    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 4    [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# ..                                                 ...     ...
# 195  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 196  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 197             [{'alias': 'tacos', 'title': 'Tacos'}]     4.0
# 198  [{'alias': 'icecream', 'title': 'Ice Cream & F...     5.0
# 199  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
#
#                                            coordinates        transactions  \
# 0       {'latitude': 40.73778, 'longitude': -74.00197}          [delivery]
# 1     {'latitude': 40.722766, 'longitude': -73.996233}            [pickup]
# 2    {'latitude': 40.733798036104304, 'longitude': ...  [pickup, delivery]
# 3    {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 4       {'latitude': 40.71958, 'longitude': -73.99734}  [pickup, delivery]
# ..                                                 ...                 ...
# 195  {'latitude': 36.75032154684149, 'longitude': -...          [delivery]
# 196    {'latitude': 36.73618, 'longitude': -119.69507}                  []
# 197  {'latitude': 36.923297, 'longitude': -119.872012}  [pickup, delivery]
# 198    {'latitude': 36.75733, 'longitude': -119.83253}          [delivery]
# 199    {'latitude': 36.75788, 'longitude': -119.80173}                  []
#
#     price                                           location         phone  \
# 0     $$$  {'address1': '103 Greenwich Ave', 'address2': ...  +12128898884
# 1      $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
# 2      $$  {'address1': '3 Greenwich Ave', 'address2': No...  +12122436546
# 3       $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 4      $$  {'address1': '186 Grand St', 'address2': '', '...  +12122261600
# ..    ...                                                ...           ...
# 195     $  {'address1': '4662 E Belmont Ave', 'address2':...  +15592559764
# 196    $$  {'address1': None, 'address2': None, 'address3...  +15597249948
# 197    $$  {'address1': '37221 Ave 12', 'address2': 'Ste ...  +15596605458
# 198     $  {'address1': '1807 W Olive Ave', 'address2': '...  +15595708000
# 199   NaN  {'address1': '805 E Olive Ave', 'address2': ''...  +15595414656
#
#       display_phone      distance
# 0    (212) 889-8884   3916.353269
# 1    (212) 965-0500   2259.040290
# 2    (212) 243-6546   3434.912792
# 3    (212) 966-4100   2197.633982
# 4    (212) 226-1600   2072.026761
# ..              ...           ...
# 195  (559) 255-9764  69375.356779
# 196  (559) 724-9948  67859.351823
# 197  (559) 660-5458  63166.053394
# 198  (559) 570-8000  73548.824090
# 199  (559) 541-4656  71784.571778
#
# [200 rows x 16 columns]

# %%
counts = df['id'].count()
counts
