# %%
import pandas as pd
import requests
import json
import re

# %%
# Import API key
from api import API_key

# %%
url = "https://api.yelp.com/v3/businesses/search"

# %%
headers = {
        'Authorization': 'Bearer ' + API_key,
        'Content-Type': 'application/json'
    }

# %%
# states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia"]
# states += ["Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland"]
# states += ["Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey"]
# states += ["New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina"]
# states += ["South Dakota", "Tennessee", "Texas", "Utah", "Vermont" ]
states = ["Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]
offsets = [0,51,101,151,201,251,301,351,401]
restaurants= []

# %%
for state in states:
    print(f'Getting data for state: {state}')
    for offset in offsets:
        print(f'Getting offset: {offset}')
        params = {'location': state,
            'limit': 50,
            'offset': offset,
            'sort_by': 'review_count',
            'term': 'food'
            }
        response = requests.get(url,  headers=headers, params=params).json()
        if 'businesses' in response:
            restaurants.extend(response['businesses'])
# Out:
# Getting data for state: Virginia
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting data for state: Washington
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting data for state: West Virginia
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting data for state: Wisconsin
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting data for state: Wyoming
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401

# %%
df = pd.DataFrame(restaurants)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1807 entries, 0 to 1806
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1807 non-null   object
#  1   alias          1807 non-null   object
#  2   name           1807 non-null   object
#  3   image_url      1807 non-null   object
#  4   is_closed      1807 non-null   bool
#  5   url            1807 non-null   object
#  6   review_count   1807 non-null   int64
#  7   categories     1807 non-null   object
#  8   rating         1807 non-null   float64
#  9   coordinates    1807 non-null   object
#  10  transactions   1807 non-null   object
#  11  price          1634 non-null   object
#  12  location       1807 non-null   object
#  13  phone          1807 non-null   object
#  14  display_phone  1807 non-null   object
#  15  distance       1807 non-null   float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 213.6+ KB
#                        id                                              alias  \
# 0  gg0KUHbpC8rCxW1Iym2LYA                        blue-mountain-brewery-afton
# 1  TmafPHIsnYiTa6i2HXzDyg  jack-browns-beer-and-burger-joint-harrisonburg...
# 2  IRbefUFKJrJfFENkck2qFw         devils-backbone-brewing-company-roseland-2
# 3  dEukVK634pxUEiZig5PCRQ                     thunderbird-cafe-mcgaheysville
# 4  Q_szQSnt_QyZJpbdwrXJZA                     the-mill-street-grill-staunton
#
#                                               name  \
# 0                            Blue Mountain Brewery
# 1  Jack Brown's Beer & Burger Joint - Harrisonburg
# 2                  Devils Backbone Brewing Company
# 3                                 Thunderbird Cafe
# 4                            The Mill Street Grill
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/E-DbVX...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/soMsow...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/RrFBqQ...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/e1RTrR...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/xED5sF...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/blue-mountain-brewery...           746
# 1  https://www.yelp.com/biz/jack-browns-beer-and-...           663
# 2  https://www.yelp.com/biz/devils-backbone-brewi...           577
# 3  https://www.yelp.com/biz/thunderbird-cafe-mcga...           561
# 4  https://www.yelp.com/biz/the-mill-street-grill...           555
#
#                                           categories  rating  \
# 0       [{'alias': 'brewpubs', 'title': 'Brewpubs'}]     4.0
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 2  [{'alias': 'tradamerican', 'title': 'American ...     3.5
# 3  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 4  [{'alias': 'tradamerican', 'title': 'American ...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 38.016237360670075, 'longitude': ...                  []
# 1  {'latitude': 38.448497287581, 'longitude': -78...  [delivery, pickup]
# 2   {'latitude': 37.870856, 'longitude': -78.918875}                  []
# 3   {'latitude': 38.37514, 'longitude': -78.7285799}          [delivery]
# 4  {'latitude': 38.1480029950747, 'longitude': -7...                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '9519 Critzers Shop Rd', 'address...  +15404568020
# 1    $$  {'address1': '80 S Main St', 'address2': '', '...  +15404335225
# 2    $$  {'address1': '200 Mosbys Run', 'address2': '',...  +14343611001
# 3    $$  {'address1': '42 Island Ford Rd', 'address2': ...  +15402895094
# 4    $$  {'address1': '1 Mill St', 'address2': '', 'add...
#
#     display_phone      distance
# 0  (540) 456-8020  52442.706359
# 1  (540) 433-5225  69182.833239
# 2  (434) 361-1001  46315.996093
# 3  (540) 289-5094  73326.658391
# 4                  34581.265894

# %%
counts = df['id'].count()
counts
# Out:
# 1807

# %%
# Specify the path and filename for the CSV file
csv_file_path_1 = 'data1.csv'
csv_file_path = 'data1.csv'

# Convert and save the DataFrame to CSV
df.to_csv(csv_file_path, index=False)

# %%
# Specify the path and filename for the CSV file
csv_file_path_1 = 'data1.csv'
csv_file_path = 'data.csv'

# %%
# Read the CSV file and create a DataFrame
df_45 = pd.read_csv(csv_file_path)
df_5 = pd.read_csv(csv_file_path_1)

# %%
df_45['id'].count()
# Out:
# 21523

# %%
df_5['id'].count()
# Out:
# 1807

# %%
combined_df = pd.concat([df_45, df_5], ignore_index=True)
combined_df['id'].count()
# Out:
# 23330

# %%
combined_df.head(2)
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23330 entries, 0 to 23329
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             23330 non-null  object
#  1   alias          23330 non-null  object
#  2   name           23330 non-null  object
#  3   image_url      23041 non-null  object
#  4   is_closed      23330 non-null  bool
#  5   url            23330 non-null  object
#  6   review_count   23330 non-null  int64
#  7   categories     23330 non-null  object
#  8   rating         23330 non-null  float64
#  9   coordinates    23330 non-null  object
#  10  transactions   23330 non-null  object
#  11  price          21537 non-null  object
#  12  location       23330 non-null  object
#  13  phone          23041 non-null  float64
#  14  display_phone  23041 non-null  object
#  15  distance       23330 non-null  float64
# dtypes: bool(1), float64(3), int64(1), object(11)
# memory usage: 2.7+ MB

# %%
combined_df.head(5)
# Out:
#                        id                                              alias  \
# 0  CcvzbAdZR7kN_HQy5i4AtA                     saws-soul-kitchen-birmingham-3
# 1  wGKlPWIZVslyMM9es7vg1A                               el-barrio-birmingham
# 2  W6Z4VGSJ5lLymR2idLNLfw      hattie-bs-hot-chicken-birmingham-birmingham-2
# 3  0ZcwpVEYRZ-ZyeLsZS2oGA  jack-browns-beer-and-burger-joint-birmingham-b...
# 4  ABK0EgFGXw_JmNNDXhyJrw                                saws-bbq-homewood-2
#
#                                             name  \
# 0                             Saw's Soul Kitchen
# 1                                      El Barrio
# 2            Hattie B's Hot Chicken - Birmingham
# 3  Jack Brown's Beer & Burger Joint - Birmingham
# 4                                      SAW's BBQ
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/SSeFX1...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/Zj1ui7...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/Ej0sPi...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/rt3yUq...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/-84d_Q...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/saws-soul-kitchen-bir...           998
# 1  https://www.yelp.com/biz/el-barrio-birmingham?...           834
# 2  https://www.yelp.com/biz/hattie-bs-hot-chicken...           720
# 3  https://www.yelp.com/biz/jack-browns-beer-and-...           695
# 4  https://www.yelp.com/biz/saws-bbq-homewood-2?a...           673
#
#                                           categories  rating  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 2  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 4            [{'alias': 'bbq', 'title': 'Barbeque'}]     4.5
#
#                                          coordinates            transactions  \
# 0  {'latitude': 33.524198528011226, 'longitude': ...            ['delivery']
# 1  {'latitude': 33.5169035, 'longitude': -86.8030...            ['delivery']
# 2   {'latitude': 33.511543, 'longitude': -86.788468}            ['delivery']
# 3  {'latitude': 33.5111334, 'longitude': -86.7883...  ['pickup', 'delivery']
# 4     {'latitude': 33.47388, 'longitude': -86.80825}            ['delivery']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '215 41st St S', 'address2': None...  1.205591e+10
# 1    $$  {'address1': '2211 2nd Ave N', 'address2': '',...  1.205868e+10
# 2    $$  {'address1': '2808 7th Ave S', 'address2': 'St...  1.205579e+10
# 3    $$  {'address1': '2811 7th Ave S', 'address2': Non...  1.205203e+10
# 4    $$  {'address1': '1008 Oxmoor Rd', 'address2': '',...  1.205879e+10
#
#     display_phone     distance
# 0  (205) 591-1409  7067.681435
# 1  (205) 868-3737  4616.413033
# 2  (205) 578-6018  6094.292242
# 3  (205) 203-4512  6130.877144
# 4  (205) 879-1937  7469.371520

# %%
combined_df.loc[combined_df['id'] == 'CcvzbAdZR7kN_HQy5i4AtA', 'categories'].values
# Out:
# array(["[{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'burgers', 'title': 'Burgers'}]"],
#       dtype=object)

# %%
state_info = []
p= ''state'(?=:)'
# Loop through each row in the DataFrame
for index, row in combined_df.iterrows():
    location = row['location']
    
    # Check if the location contains 'state': 'AL'
    if '"state":' in location:
        combined_df[combined_df['location'].str.contains(p)]
        state_info.append(state)
    else:
        state_info.append(None) 
# Add the extracted state info as a new column
state_info
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]
