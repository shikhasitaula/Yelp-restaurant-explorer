# %%
# Dependencies
import requests
import json
import pandas as pd
# Import the API key
# from yelp import API_key

# %%
# Import API key
from yelp import API_key

# %%
url = "https://api.yelp.com/v3/businesses/search"

# %%
headers = {
        'Authorization': 'Bearer ' + API_key,
        'Content-Type': 'application/json'
    }

# %%
# headers = {'Authorization': 'bearer %s' % MY_API_KEY}
states = ['New York', 'California']
restaurants= []

# %%
for state in states:
    params = {'location': state,
          'limit': 50
        }

# %%
 # Pretty print JSON for all launchpads
response = requests.get(url,  headers=headers, params=params).json()
print(json.dumps(response, indent=4, sort_keys=False))

if 'businesses' in response:
        restaurants.extend(response['businesses', [0]])
# Out:
# {
#     "businesses": [
#         {
#             "id": "9ZURLR_1ys3lN3Li8E_C0w",
#             "alias": "heirloom-fresno-2",
#             "name": "Heirloom",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/7fjE8hBYMvkA9U_DGB1jkA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/heirloom-fresno-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1983,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.85648251011611,
#                 "longitude": -119.78372133927978
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "8398 N Fresno St",
#                 "address2": "Ste 101",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "8398 N Fresno St",
#                     "Ste 101",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15592289735",
#             "display_phone": "(559) 228-9735",
#             "distance": 62366.05109715377
#         },
#         {
#             "id": "xiPYoKcZ-QacPjrvUFRkpQ",
#             "alias": "the-annex-kitchen-fresno-2",
#             "name": "The Annex Kitchen",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Y-UPgyUgN9TEIwTGA0Irhg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-annex-kitchen-fresno-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1530,
#             "categories": [
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.80758,
#                 "longitude": -119.83229
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "2257 W Shaw Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2257 W Shaw Ave",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15592488512",
#             "display_phone": "(559) 248-8512",
#             "distance": 69284.52751119724
#         },
#         {
#             "id": "_Ae3d3r7Ut-VAUoBcFYs7Q",
#             "alias": "saizon-fresno",
#             "name": "Saizon",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/K7CSA_GW8tRh-rceuLMVMQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/saizon-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 327,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.86728041008362,
#                 "longitude": -119.7304528449808
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "2894 E Shepherd Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2894 E Shepherd Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15595529688",
#             "display_phone": "(559) 552-9688",
#             "distance": 58327.86771931272
#         },
#         {
#             "id": "_9aI8_nUwnBTSlPEbWNdHw",
#             "alias": "mochuelo-fresno",
#             "name": "Mochuelo",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/7JWSi-fKZ2oZHLE_d2pzRw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mochuelo-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 394,
#             "categories": [
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 },
#                 {
#                     "alias": "spanish",
#                     "title": "Spanish"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.807753,
#                 "longitude": -119.833184
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery",
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "2305 W Shaw Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2305 W Shaw Ave",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15593485555",
#             "display_phone": "(559) 348-5555",
#             "distance": 69334.71745495437
#         },
#         {
#             "id": "Sfpb-erwFWTp_HJ3kNRYWA",
#             "alias": "coltons-social-house-clovis",
#             "name": "Colton's Social House",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ENIJswpI96BZ18WHWgkp6g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/coltons-social-house-clovis?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1532,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.80802,
#                 "longitude": -119.69427
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery",
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "1150 Shaw Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Clovis",
#                 "zip_code": "93612",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1150 Shaw Ave",
#                     "Clovis, CA 93612"
#                 ]
#             },
#             "phone": "+15597216655",
#             "display_phone": "(559) 721-6655",
#             "distance": 61663.21924519196
#         },
#         {
#             "id": "SUrXfIWTrfwbQB4UD98-0w",
#             "alias": "the-lime-lite-fresno",
#             "name": "The Lime Lite",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/N4-t5RbnclHDTNFMjHMs6g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-lime-lite-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 470,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.808791,
#                 "longitude": -119.809706
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1054 W Shaw Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1054 W Shaw Ave",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15592241054",
#             "display_phone": "(559) 224-1054",
#             "distance": 67857.03754247453
#         },
#         {
#             "id": "GPP5E-f1dzAN08jNogYCjw",
#             "alias": "smokehouse-41-oakhurst",
#             "name": "Smokehouse 41",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/HcfpJdd-Xhy9KsNIZs27dw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/smokehouse-41-oakhurst?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 723,
#             "categories": [
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 },
#                 {
#                     "alias": "smokehouse",
#                     "title": "Smokehouse"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.33914,
#                 "longitude": -119.64334
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "40713 Hwy 41",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Oakhurst",
#                 "zip_code": "93644",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "40713 Hwy 41",
#                     "Oakhurst, CA 93644"
#                 ]
#             },
#             "phone": "+15596422271",
#             "display_phone": "(559) 642-2271",
#             "distance": 30971.077571383135
#         },
#         {
#             "id": "Oe2yeFzamknh4NvRBoJWlw",
#             "alias": "13-prime-steak-clovis-3",
#             "name": "13 Prime Steak",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/gfoazhGJpgafm2_mATiArA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/13-prime-steak-clovis-3?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 431,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.85358,
#                 "longitude": -119.72805
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1345 N Willow Ave",
#                 "address2": "Ste 190",
#                 "address3": null,
#                 "city": "Clovis",
#                 "zip_code": "93619",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1345 N Willow Ave",
#                     "Ste 190",
#                     "Clovis, CA 93619"
#                 ]
#             },
#             "phone": "+15592161313",
#             "display_phone": "(559) 216-1313",
#             "distance": 59356.54690292182
#         },
#         {
#             "id": "j1Zoqb_mNnrliL-Xp6_Klg",
#             "alias": "lazy-dog-fresno-3",
#             "name": "Lazy Dog",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/tTTVFlqCRovxo3r8U1g87w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/lazy-dog-fresno-3?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1199,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 },
#                 {
#                     "alias": "comfortfood",
#                     "title": "Comfort Food"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.85118,
#                 "longitude": -119.79151
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "7965 N Blackstone Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "7965 N Blackstone Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15596915300",
#             "display_phone": "(559) 691-5300",
#             "distance": 63272.268564196434
#         },
#         {
#             "id": "ivx1E6-pW2TjxSG89fQagw",
#             "alias": "red-apple-cafe-fresno",
#             "name": "Red Apple Cafe",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vauGirZt92gfMCWChZYcRQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/red-apple-cafe-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1287,
#             "categories": [
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "cafes",
#                     "title": "Cafes"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.837659,
#                 "longitude": -119.801605
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "488 W Herndon Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93650",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "488 W Herndon Ave",
#                     "Fresno, CA 93650"
#                 ]
#             },
#             "phone": "+15592611505",
#             "display_phone": "(559) 261-1505",
#             "distance": 64989.236683342264
#         },
#         {
#             "id": "WlJqfuAfu9Mo3E-tZznsKw",
#             "alias": "mammoth-rock-brasserie-mammoth-lakes-2",
#             "name": "Mammoth Rock Brasserie",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wT3rBmpTTrc3fdm2p7Tnkg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mammoth-rock-brasserie-mammoth-lakes-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 405,
#             "categories": [
#                 {
#                     "alias": "brasseries",
#                     "title": "Brasseries"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.63679,
#                 "longitude": -118.96491
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "3029 Chateau Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3029 Chateau Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609344200",
#             "display_phone": "(760) 934-4200",
#             "distance": 50873.632013725946
#         },
#         {
#             "id": "0agq0wMl5TAyH4fSxN8NUA",
#             "alias": "skadi-mammoth-lakes-2",
#             "name": "SKADI",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/f9dDghIjtnguBjWA88ISjw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/skadi-mammoth-lakes-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 422,
#             "categories": [
#                 {
#                     "alias": "modern_european",
#                     "title": "Modern European"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 37.6512,
#                 "longitude": -118.9829
#             },
#             "transactions": [],
#             "price": "$$$$",
#             "location": {
#                 "address1": "94 Berner St",
#                 "address2": "Ste A",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "94 Berner St",
#                     "Ste A",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609140962",
#             "display_phone": "(760) 914-0962",
#             "distance": 51284.62489949966
#         },
#         {
#             "id": "N2eqSo_1vpFcICQnZzq3hA",
#             "alias": "rocket-dog-gourmet-brats-and-brew-fresno",
#             "name": "Rocket Dog Gourmet Brats & Brew",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Ux2fP0RhzuXVdAWKgU3Vhw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/rocket-dog-gourmet-brats-and-brew-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1024,
#             "categories": [
#                 {
#                     "alias": "hotdog",
#                     "title": "Hot Dogs"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8088049482694,
#                 "longitude": -119.788546097112
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "88 E Shaw Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93710",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "88 E Shaw Ave",
#                     "Fresno, CA 93710"
#                 ]
#             },
#             "phone": "+15592838096",
#             "display_phone": "(559) 283-8096",
#             "distance": 66631.82021258549
#         },
#         {
#             "id": "kVEGnADQh8_PZ481ZefN7A",
#             "alias": "pismos-coastal-grill-fresno",
#             "name": "Pismo's Coastal Grill",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vGTlxr9EGBcjKLE5QDkQ1g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/pismos-coastal-grill-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1839,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.8514568756632,
#                 "longitude": -119.79364423772844
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery",
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "7937 N Blackstone Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "7937 N Blackstone Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15594399463",
#             "display_phone": "(559) 439-9463",
#             "distance": 63376.24494309736
#         },
#         {
#             "id": "Vp4h70Ok9RYj8lAAUOfqAQ",
#             "alias": "batter-up-pancakes-fresno-2",
#             "name": "Batter Up Pancakes",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/JOl3AbgKik3_SFYEYd9zUg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/batter-up-pancakes-fresno-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1421,
#             "categories": [
#                 {
#                     "alias": "pancakes",
#                     "title": "Pancakes"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8525455,
#                 "longitude": -119.7582005
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "8029 N Cedar Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "8029 N Cedar Ave",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15594401221",
#             "display_phone": "(559) 440-1221",
#             "distance": 61177.632336838775
#         },
#         {
#             "id": "Ollnz3tVka1bMFbryAnn0g",
#             "alias": "hino-oishi-fresno",
#             "name": "Hino Oishi",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/TmbE4rKeDRjnHBGFYl92Cw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hino-oishi-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1078,
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8116445316553,
#                 "longitude": -119.73440675283616
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "3091 E Campus Pointe Dr",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93710",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3091 E Campus Pointe Dr",
#                     "Fresno, CA 93710"
#                 ]
#             },
#             "phone": "+15597654657",
#             "display_phone": "(559) 765-4657",
#             "distance": 63392.155030950526
#         },
#         {
#             "id": "gwANdrsPZr3ZVAqN52vwqg",
#             "alias": "the-elderberry-house-oakhurst-2",
#             "name": "The Elderberry House",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/NkGEpjKf31sgXaT_XHassQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-elderberry-house-oakhurst-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 283,
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.327100397143525,
#                 "longitude": -119.66091834110446
#             },
#             "transactions": [],
#             "price": "$$$$",
#             "location": {
#                 "address1": "48688 Victoria Ln",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Oakhurst",
#                 "zip_code": "93644",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "48688 Victoria Ln",
#                     "Oakhurst, CA 93644"
#                 ]
#             },
#             "phone": "+15596836800",
#             "display_phone": "(559) 683-6800",
#             "distance": 32143.065198151613
#         },
#         {
#             "id": "UVW_GF1zGsKN8OBOTGQUGA",
#             "alias": "annesso-pizzeria-fresno-2",
#             "name": "Annesso Pizzeria",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/QjB-SHBhreQj7a8ZC723TA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/annesso-pizzeria-fresno-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 457,
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.85922376493786,
#                 "longitude": -119.7830944195512
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "8484 N Friant Rd",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "8484 N Friant Rd",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15599818995",
#             "display_phone": "(559) 981-8995",
#             "distance": 62104.566315205986
#         },
#         {
#             "id": "Y58wkqUQ_-Kz8_o8qnP15A",
#             "alias": "charles-street-dinner-house-mariposa",
#             "name": "Charles Street Dinner House",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/CfDdO02388XApD2oEqQgCQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/charles-street-dinner-house-mariposa?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 549,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.48545467039154,
#                 "longitude": -119.96607841142622
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "5043 Hwy 140 and 7th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mariposa",
#                 "zip_code": "95338",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "5043 Hwy 140 and 7th St",
#                     "Mariposa, CA 95338"
#                 ]
#             },
#             "phone": "+12099662366",
#             "display_phone": "(209) 966-2366",
#             "distance": 63215.82307229185
#         },
#         {
#             "id": "dCAnqtdMqbvZXIJt2FA22g",
#             "alias": "the-mogul-restaurant-mammoth-lakes",
#             "name": "The Mogul Restaurant",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/gGjl6hqMnW2QlZ9PTlIQ1A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-mogul-restaurant-mammoth-lakes?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 611,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.64519,
#                 "longitude": -118.96671
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "1528 Tavern Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1528 Tavern Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609343039",
#             "display_phone": "(760) 934-3039",
#             "distance": 51550.001167560644
#         },
#         {
#             "id": "jGBBu6ppRzyPjerTLr_PaQ",
#             "alias": "sabor-cocina-latina-and-bar-fresno",
#             "name": "Sabor Cocina Latina & Bar",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/EeGd4sikgevaJmyYojhzLw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/sabor-cocina-latina-and-bar-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 347,
#             "categories": [
#                 {
#                     "alias": "latin",
#                     "title": "Latin American"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.851711,
#                 "longitude": -119.806469
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "7845 N Palm Ave",
#                 "address2": "Ste 104",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93711",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "7845 N Palm Ave",
#                     "Ste 104",
#                     "Fresno, CA 93711"
#                 ]
#             },
#             "phone": "+15593751644",
#             "display_phone": "(559) 375-1644",
#             "distance": 64135.99001913438
#         },
#         {
#             "id": "tqo1WOpnT2nZQUJSUAIAFA",
#             "alias": "vintage-steakhouse-coarsegold-2",
#             "name": "Vintage Steakhouse",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Jm-gcNx79M-we_waG2CQgw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/vintage-steakhouse-coarsegold-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 102,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.2120254,
#                 "longitude": -119.6995546
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "711 Lucky Ln",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Coarsegold",
#                 "zip_code": "93614",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "711 Lucky Ln",
#                     "Coarsegold, CA 93614"
#                 ]
#             },
#             "phone": "+15596925200",
#             "display_phone": "(559) 692-5200",
#             "distance": 35434.28322978343
#         },
#         {
#             "id": "byUUxQV1CSOqJ4aFklMVrA",
#             "alias": "yosemite-national-park-yosemite-national-park-11",
#             "name": "Yosemite National Park",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/cCgZvrU8qSWzcG0MGNXJAg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/yosemite-national-park-yosemite-national-park-11?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1276,
#             "categories": [
#                 {
#                     "alias": "parks",
#                     "title": "Parks"
#                 },
#                 {
#                     "alias": "campgrounds",
#                     "title": "Campgrounds"
#                 },
#                 {
#                     "alias": "hiking",
#                     "title": "Hiking"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.747525,
#                 "longitude": -119.585552
#             },
#             "transactions": [],
#             "location": {
#                 "address1": null,
#                 "address2": null,
#                 "address3": null,
#                 "city": "Yosemite National Park",
#                 "zip_code": "95389",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "Yosemite National Park, CA 95389"
#                 ]
#             },
#             "phone": "+12093720200",
#             "display_phone": "(209) 372-0200",
#             "distance": 58828.37667996651
#         },
#         {
#             "id": "aEbC9m5SZC09gfNR2UYWxQ",
#             "alias": "restaurant-at-convict-lake-mammoth-lakes",
#             "name": "Restaurant At Convict Lake",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-AyKfycmDfx6ZVzxYjRj1Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/restaurant-at-convict-lake-mammoth-lakes?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 248,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.5980082466189,
#                 "longitude": -118.849853239954
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "2000 Convict Lake Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "2000 Convict Lake Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609343800",
#             "display_phone": "(760) 934-3800",
#             "distance": 54487.76722818949
#         },
#         {
#             "id": "dwxU9Nke7wr3RZze0ivkTg",
#             "alias": "yosemite-ranch-fresno-5",
#             "name": "Yosemite Ranch",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/FT0ZsTBD4uaAFZv0_bLLLA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/yosemite-ranch-fresno-5?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1122,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.86698,
#                 "longitude": -119.75625
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1520 E Champlain Dr",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93720",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1520 E Champlain Dr",
#                     "Fresno, CA 93720"
#                 ]
#             },
#             "phone": "+15594344403",
#             "display_phone": "(559) 434-4403",
#             "distance": 59866.69132309814
#         },
#         {
#             "id": "KGsOt2vpYCrAf5uLNb0BWQ",
#             "alias": "the-warming-hut-mammoth-lakes-2",
#             "name": "The Warming Hut",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/LGqkGxms5nity1rbkbbzFw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-warming-hut-mammoth-lakes-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 674,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "comfortfood",
#                     "title": "Comfort Food"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 37.6411,
#                 "longitude": -118.96619
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "343 Old Mammoth Rd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "343 Old Mammoth Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609650549",
#             "display_phone": "(760) 965-0549",
#             "distance": 51229.543064896505
#         },
#         {
#             "id": "M6qUGNq8_25RUs8Q9KcLaQ",
#             "alias": "duceys-on-the-lake-bass-lake-2",
#             "name": "Ducey's on the Lake",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/ht5jtZwkBNxPV0ryJLWTkA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/duceys-on-the-lake-bass-lake-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 582,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.3189103,
#                 "longitude": -119.5570908
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "39255 Marina Dr",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Bass Lake",
#                 "zip_code": "93604",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "39255 Marina Dr",
#                     "Bass Lake, CA 93604"
#                 ]
#             },
#             "phone": "+15596423131",
#             "display_phone": "(559) 642-3131",
#             "distance": 22996.202755920232
#         },
#         {
#             "id": "A_7HXAZmYEEQDe8mk27urA",
#             "alias": "oakhurst-grill-and-whiskey-41-lounge-oakhurst",
#             "name": "Oakhurst Grill and Whiskey 41 Lounge",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/T5jXXUmKjniD-8gdS03V9A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/oakhurst-grill-and-whiskey-41-lounge-oakhurst?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 331,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.33603980916658,
#                 "longitude": -119.646133705974
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "40530 Hwy 41",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Oakhurst",
#                 "zip_code": "93644",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "40530 Hwy 41",
#                     "Oakhurst, CA 93644"
#                 ]
#             },
#             "phone": "+15596412477",
#             "display_phone": "(559) 641-2477",
#             "distance": 31091.779982034124
#         },
#         {
#             "id": "hgZUMSrhohHkGKeCEiiy-A",
#             "alias": "south-gate-brewing-company-oakhurst-4",
#             "name": "South Gate Brewing Company",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/8HtTXcyTyw5SlzqeqtHviA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/south-gate-brewing-company-oakhurst-4?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 1496,
#             "categories": [
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 },
#                 {
#                     "alias": "brewpubs",
#                     "title": "Brewpubs"
#                 },
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.3331104,
# ...
#             "coordinates": {
#                 "latitude": 36.83482,
#                 "longitude": -119.87954
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "6701 N Milburn Ave",
#                 "address2": "Ste 130",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93722",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "6701 N Milburn Ave",
#                     "Ste 130",
#                     "Fresno, CA 93722"
#                 ]
#             },
#             "phone": "+15593751285",
#             "display_phone": "(559) 375-1285",
#             "distance": 70076.25793471113
#         },
#         {
#             "id": "PGUM86R57lXPi4LFHJWhAg",
#             "alias": "dish-bistro-mammoth-lakes-2",
#             "name": "Dish Bistro",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/LsYY8ZKxqOli17yOJZ4d1w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/dish-bistro-mammoth-lakes-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 174,
#             "categories": [
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 },
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 37.63753,
#                 "longitude": -118.966839
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "588 Old Mammoth Rd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "588 Old Mammoth Rd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609203738",
#             "display_phone": "(760) 920-3738",
#             "distance": 50858.537843962964
#         },
#         {
#             "id": "-8_Vm8hg9gi2gRD3UpnrOg",
#             "alias": "school-house-restaurant-and-tavern-sanger-3",
#             "name": "School House Restaurant & Tavern",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/xB0Ubhe0YwFeVuMleTTPtg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/school-house-restaurant-and-tavern-sanger-3?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 572,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.71935,
#                 "longitude": -119.44788
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1018 S Frankwood Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Sanger",
#                 "zip_code": "93657",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1018 S Frankwood Ave",
#                     "Sanger, CA 93657"
#                 ]
#             },
#             "phone": "+15597873271",
#             "display_phone": "(559) 787-3271",
#             "distance": 62202.88695382637
#         },
#         {
#             "id": "gsJYTks9w2BQOsZnJNFnwA",
#             "alias": "austria-hof-restaurant-mammoth-lakes",
#             "name": "Austria Hof Restaurant",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Zh660YZWUDF37En7FZ_kMQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/austria-hof-restaurant-mammoth-lakes?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 412,
#             "categories": [
#                 {
#                     "alias": "german",
#                     "title": "German"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.647592,
#                 "longitude": -119.000261
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "924 Canyon Blvd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "924 Canyon Blvd",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609342764",
#             "display_phone": "(760) 934-2764",
#             "distance": 50122.66527259276
#         },
#         {
#             "id": "M7dZODPoiOAJHdKzIWMPHw",
#             "alias": "morrisons-restaurant-and-bar-mammoth-lakes",
#             "name": "Morrison's Restaurant and Bar",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/jvEFpMlGUUJGyi846ZRC4w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/morrisons-restaurant-and-bar-mammoth-lakes?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 328,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "salad",
#                     "title": "Salad"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 37.6490236,
#                 "longitude": -118.974322
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "3516 Main St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Mammoth Lakes",
#                 "zip_code": "93546",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "3516 Main St",
#                     "Mammoth Lakes, CA 93546"
#                 ]
#             },
#             "phone": "+17609347427",
#             "display_phone": "(760) 934-7427",
#             "distance": 51519.93528539423
#         },
#         {
#             "id": "zax7GbinnYMWMtgW9gdZQg",
#             "alias": "cracked-pepper-bistro-fresno-2",
#             "name": "Cracked Pepper Bistro",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/k-gX8FMNZThfm4iFy3AhUQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/cracked-pepper-bistro-fresno-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 539,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 36.8355750271176,
#                 "longitude": -119.810515898148
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "6737 N Palm Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93704",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "6737 N Palm Ave",
#                     "Fresno, CA 93704"
#                 ]
#             },
#             "phone": "+15592229119",
#             "display_phone": "(559) 222-9119",
#             "distance": 65691.84558015227
#         },
#         {
#             "id": "VvPOfhbH6BH3I-vFG1hALQ",
#             "alias": "ramen-hayashi-clovis",
#             "name": "Ramen Hayashi",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/LI8uicsv_f-3QODigWYEZA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/ramen-hayashi-clovis?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 507,
#             "categories": [
#                 {
#                     "alias": "ramen",
#                     "title": "Ramen"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.83788190993908,
#                 "longitude": -119.68518180642032
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "1755 Herndon Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Clovis",
#                 "zip_code": "93611",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "1755 Herndon Ave",
#                     "Clovis, CA 93611"
#                 ]
#             },
#             "phone": "+15599406400",
#             "display_phone": "(559) 940-6400",
#             "distance": 58457.76546798549
#         },
#         {
#             "id": "6uDV7SjvxlTfC3rXqFhkBQ",
#             "alias": "bay-leaf-indian-kitchen-fresno",
#             "name": "Bay Leaf Indian Kitchen",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KW5Z_gfTs7FOJJ6EcbH33Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/bay-leaf-indian-kitchen-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 252,
#             "categories": [
#                 {
#                     "alias": "indpak",
#                     "title": "Indian"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.808642,
#                 "longitude": -119.870583
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "4368 W Shaw Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Fresno",
#                 "zip_code": "93722",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "4368 W Shaw Ave",
#                     "Fresno, CA 93722"
#                 ]
#             },
#             "phone": "+15595156464",
#             "display_phone": "(559) 515-6464",
#             "distance": 71548.77281641682
#         },
#         {
#             "id": "SZBLnPaU1tYUbixG5IYvlQ",
#             "alias": "carrillos-mexican-food-clovis",
#             "name": "Carrillo's Mexican Food",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/GxsN-hmqA9efLQCmiMeNuA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/carrillos-mexican-food-clovis?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 687,
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.8234714433902,
#                 "longitude": -119.712107665837
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "151 W Bullard Ave",
#                 "address2": "Ste 101",
#                 "address3": null,
#                 "city": "Clovis",
#                 "zip_code": "93612",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "151 W Bullard Ave",
#                     "Ste 101",
#                     "Clovis, CA 93612"
#                 ]
#             },
#             "phone": "+15593255688",
#             "display_phone": "(559) 325-5688",
#             "distance": 61155.33560006727
#         },
#         {
#             "id": "XdTyuEoZLq4U3GXR7-HdIg",
#             "alias": "l-aperitif-bistro-fusion-fresno",
#             "name": "L'Aperitif Bistro Fusion",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/kUGl_dQslUFK3hQjXhYl7g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/l-aperitif-bistro-fusion-fresno?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ",
#             "review_count": 265,
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 36.834793,
#                 "longitude": -119.753049
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "location": {
#                 "address1": "6650 N Cedar Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Fresno",
#                 "zip_code": "93710",
#                 "country": "US",
#                 "state": "CA",
#                 "display_address": [
#                     "6650 N Cedar Ave",
#                     "Fresno, CA 93710"
#                 ]
#             },
#             "phone": "+15594723824",
#             "display_phone": "(559) 472-3824",
#             "distance": 62383.95648135885
#         }
#     ],
#     "total": 3200,
#     "region": {
#         "center": {
#             "longitude": -119.3060302734375,
#             "latitude": 37.26682643661537
#         }
#     }
# }
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       3 print(json.dumps(response, indent=4, sort_keys=False))
#       5 if 'businesses' in response:
# ----> 6        restaurants.extend(response['businesses', [0]])
#
# TypeError: unhashable type: 'list'

# %%
df = pd.DataFrame(restaurants)
df.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: []
# Index: []>

# %%
# Print the json (pretty printed)
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "businesses": [
#         {
#             "alias": "the-kings-feast-plantersville-2",
#             "categories": [
#                 {
#                     "alias": "dinnertheater",
#                     "title": "Dinner Theater"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 30.2557695824901,
#                 "longitude": -95.8397671089066
#             },
#             "display_phone": "(800) 224-0761",
#             "distance": 61507.52722304298,
#             "id": "o8IRbAdynoBaCKm-Zaj6LA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/EbNbmauF-Xc4x0833aQk-g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "21778 Fm-1774",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Plantersville",
#                 "country": "US",
#                 "display_address": [
#                     "21778 Fm-1774",
#                     "Plantersville, TX 77363"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77363"
#             },
#             "name": "The King's Feast",
#             "phone": "+18002240761",
#             "price": "$$$$",
#             "rating": 4.5,
#             "review_count": 7,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/the-kings-feast-plantersville-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "the-ginger-mule-houston",
#             "categories": [
#                 {
#                     "alias": "vegan",
#                     "title": "Vegan"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.803238,
#                 "longitude": -95.405455
#             },
#             "display_phone": "(713) 876-4768",
#             "distance": 3966.590345036093,
#             "id": "tGNsatvwwYGwb9sd14yKVQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/o0YzK71cOZlwcQ1_2KrfdQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "449 W 19th St",
#                 "address2": "Ste C200",
#                 "address3": "",
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "449 W 19th St",
#                     "Ste C200",
#                     "Houston, TX 77008"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77008"
#             },
#             "name": "The Ginger Mule",
#             "phone": "+17138764768",
#             "rating": 5.0,
#             "review_count": 69,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/the-ginger-mule-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "rooster-and-rice-houston",
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "chickenshop",
#                     "title": "Chicken Shop"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.816916598862413,
#                 "longitude": -95.42140630000004
#             },
#             "display_phone": "(713) 993-6581",
#             "distance": 1909.21210692086,
#             "id": "MeyUXf7jcgF-jeHnLZk3vg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/PnDMB4daPvDtn4Wf5KbR9A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1223 W 34th St",
#                 "address2": "Ste C-400",
#                 "address3": "",
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "1223 W 34th St",
#                     "Ste C-400",
#                     "Houston, TX 77018"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77018"
#             },
#             "name": "Rooster & Rice",
#             "phone": "+17139936581",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 74,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/rooster-and-rice-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "moon-rabbit-houston",
#             "categories": [
#                 {
#                     "alias": "vietnamese",
#                     "title": "Vietnamese"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.80292,
#                 "longitude": -95.40829
#             },
#             "display_phone": "(713) 684-3991",
#             "distance": 3842.9124384748193,
#             "id": "gOICzAHTAqfSiFGkNH2yzQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/6udPxvNTCBT1CAcVWkkscA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "605 W 19th St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "605 W 19th St",
#                     "Houston, TX 77008"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77008"
#             },
#             "name": "Moon Rabbit",
#             "phone": "+17136843991",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 195,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/moon-rabbit-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "stuffed-belly-houston",
#             "categories": [
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.80274,
#                 "longitude": -95.49142
#             },
#             "display_phone": "(832) 224-5422",
#             "distance": 7060.626696499852,
#             "id": "GySi8cCYfkm_usS12Di-iQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/qNcNTZWzNTX4ZuWP9fuQVw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "8133 Long Point Rd",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "8133 Long Point Rd",
#                     "Houston, TX 77055"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77055"
#             },
#             "name": "Stuffed Belly",
#             "phone": "+18322245422",
#             "rating": 4.5,
#             "review_count": 27,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/stuffed-belly-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "chilantro-bbq-houston-2",
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "catering",
#                     "title": "Caterers"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.79492395659671,
#                 "longitude": -95.40970411151648
#             },
#             "display_phone": "(281) 975-0129",
#             "distance": 4592.859212337199,
#             "id": "qn9SPk0vTisMaAqF3Vu-QQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/1bUKqGB3YTa229O1wNvdzg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1324 N Shepherd Dr",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "1324 N Shepherd Dr",
#                     "Houston, TX 77008"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77008"
#             },
#             "name": "Chi'Lantro BBQ",
#             "phone": "+12819750129",
#             "rating": 4.0,
#             "review_count": 48,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/chilantro-bbq-houston-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "two-hands-spring",
#             "categories": [
#                 {
#                     "alias": "hotdog",
#                     "title": "Hot Dogs"
#                 },
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "juicebars",
#                     "title": "Juice Bars & Smoothies"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 30.072476587565067,
#                 "longitude": -95.43647321164651
#             },
#             "display_phone": "",
#             "distance": 26607.58995072275,
#             "id": "VQJTERbqvzWF_EdCEBVmJA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/KWyum7OHduwQHet3JQwx3w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "21117 North Fwy",
#                 "address2": "Ste 200",
#                 "address3": null,
#                 "city": "Spring",
#                 "country": "US",
#                 "display_address": [
#                     "21117 North Fwy",
#                     "Ste 200",
#                     "Spring, TX 77388"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77388"
#             },
#             "name": "Two Hands",
#             "phone": "",
#             "rating": 4.5,
#             "review_count": 6,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/two-hands-spring?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "yoyos-hot-dog-houston-18",
#             "categories": [
#                 {
#                     "alias": "hotdog",
#                     "title": "Hot Dogs"
#                 },
#                 {
#                     "alias": "foodstands",
#                     "title": "Food Stands"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.770711692244436,
#                 "longitude": -95.40821655397576
#             },
#             "display_phone": "(281) 783-4180",
#             "distance": 7200.014213506786,
#             "id": "nAMLvssDVn3o-QN7kz0tKw",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/XjZT1HtBRs3iZVjC6Mhqsg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4620 Washington Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "4620 Washington Ave",
#                     "Houston, TX 77007"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77007"
#             },
#             "name": "Yoyo's Hot Dog",
#             "phone": "+12817834180",
#             "rating": 5.0,
#             "review_count": 13,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/yoyos-hot-dog-houston-18?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "hui-lau-shan-houston",
#             "categories": [
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.702663290535483,
#                 "longitude": -95.5534078
#             },
#             "display_phone": "",
#             "distance": 18956.996270024065,
#             "id": "ajIYOa0rJh3yuFSgTxRZjg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/0xlrckLLrEkOOZnsrAT9Hg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "9889 Bellaire Blvd",
#                 "address2": "Ste C317",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "9889 Bellaire Blvd",
#                     "Ste C317",
#                     "Houston, TX 77036"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77036"
#             },
#             "name": "Hui Lau Shan",
#             "phone": "",
#             "rating": 4.5,
#             "review_count": 59,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/hui-lau-shan-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "two-hands-corn-dogs-houston-3",
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "hotdog",
#                     "title": "Hot Dogs"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.92387840387229,
#                 "longitude": -95.599392
#             },
#             "display_phone": "(281) 653-9123",
#             "distance": 19413.096918129573,
#             "id": "sUimAaFoJtTzleoVD4ZfLQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/UWuAOjKaIddfszYDo2dFpQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "12149 Fm 1960",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "12149 Fm 1960",
#                     "Houston, TX 77065"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77065"
#             },
#             "name": "Two Hands Corn Dogs",
#             "phone": "+12816539123",
#             "price": "$",
#             "rating": 4.0,
#             "review_count": 3,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/two-hands-corn-dogs-houston-3?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "kpot-korean-bbq-and-hot-pot-no-title-5",
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "hotpot",
#                     "title": "Hot Pot"
#                 },
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.956721,
#                 "longitude": -95.5444013
#             },
#             "display_phone": "(281) 741-3890",
#             "distance": 17771.364939399293,
#             "id": "CDwkaQDxVE5Vs8fktjrT2Q",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/QEev6OTuqM58Ev6J2CCljg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "17575 Tomball Pkwy",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "17575 Tomball Pkwy",
#                     "Houston, TX 77064"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77064"
#             },
#             "name": "KPOT Korean BBQ & Hot Pot",
#             "phone": "+12817413890",
#             "rating": 3.5,
#             "review_count": 24,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/kpot-korean-bbq-and-hot-pot-no-title-5?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "tonys-italian-delicatessen-montgomery-6",
#             "categories": [
#                 {
#                     "alias": "delis",
#                     "title": "Delis"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 30.363356657157283,
#                 "longitude": -95.61204107810246
#             },
#             "display_phone": "(936) 588-4800",
#             "distance": 61559.89081103194,
#             "id": "YkxllzaO7VcQfmigJp23DQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/i0PSfC4Y4ZFb06k8dYQ39g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "16283 Hwy 105 W",
#                 "address2": "Ste 9",
#                 "address3": "",
#                 "city": "Montgomery",
#                 "country": "US",
#                 "display_address": [
#                     "16283 Hwy 105 W",
#                     "Ste 9",
#                     "Montgomery, TX 77356"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77356"
#             },
#             "name": "Tony's Italian Delicatessen",
#             "phone": "+19365884800",
#             "price": "$$",
#             "rating": 5.0,
#             "review_count": 773,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/tonys-italian-delicatessen-montgomery-6?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "dona-letis-houston-2",
#             "categories": [
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.77844,
#                 "longitude": -95.42978
#             },
#             "display_phone": "(832) 858-3917",
#             "distance": 6103.243272032422,
#             "id": "0Y43kRX-FXSwgE9uP5x_qA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/X_XT_gDIwHhibyBpKDFUsQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "7340 Washington Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "7340 Washington Ave",
#                     "Houston, TX 77007"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77007"
#             },
#             "name": "Dona Leti's",
#             "phone": "+18328583917",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 192,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/dona-letis-houston-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "sao-lao-thai-caf\u00e9-houston-2",
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "laotian",
#                     "title": "Laotian"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.83984,
#                 "longitude": -95.41125
#             },
#             "display_phone": "(832) 203-5920",
#             "distance": 1705.1648842335605,
#             "id": "fw-0MMShdwiNNLZgCZuDiw",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xPo_7NlOL40wb39IpasGwg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5013 N Shepherd Dr",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "5013 N Shepherd Dr",
#                     "Houston, TX 77018"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77018"
#             },
#             "name": "Sao Lao Thai Caf\u00e9",
#             "phone": "+18322035920",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 174,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/sao-lao-thai-caf%C3%A9-houston-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "mochinut-houston-heights-houston",
#             "categories": [
#                 {
#                     "alias": "donuts",
#                     "title": "Donuts"
#                 },
#                 {
#                     "alias": "bubbletea",
#                     "title": "Bubble Tea"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.817022,
#                 "longitude": -95.428731
#             },
#             "display_phone": "(281) 501-3135",
#             "distance": 1814.7537911107388,
#             "id": "HuIt3IohXd1qEHdIxWFDWg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/5hX79XlU4cIpEjQP6pYBtQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1717 W 34th St",
#                 "address2": "Ste 900",
#                 "address3": "",
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "1717 W 34th St",
#                     "Ste 900",
#                     "Houston, TX 77018"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77018"
#             },
#             "name": "Mochinut Houston Heights",
#             "phone": "+12815013135",
#             "rating": 4.5,
#             "review_count": 11,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/mochinut-houston-heights-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "burger-bodega-houston-2",
#             "categories": [
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.770682,
#                 "longitude": -95.407109
#             },
#             "display_phone": "",
#             "distance": 7233.837542202973,
#             "id": "LHIsYBkPlCSiLmaoo3xnhQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/uGpsLFP4I5FpsFkvhKzfbw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4520 Washington Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "4520 Washington Ave",
#                     "Houston, TX 77007"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77007"
#             },
#             "name": "Burger Bodega",
#             "phone": "",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 249,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/burger-bodega-houston-2?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "laynes-chicken-fingers-houston",
#             "categories": [
#                 {
#                     "alias": "chicken_wings",
#                     "title": "Chicken Wings"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.81379999963967,
#                 "longitude": -95.4290998
#             },
#             "display_phone": "(713) 244-5299",
#             "distance": 2178.11006131111,
#             "id": "Ai_DdeIq4oQ5uXc8Vs3mfA",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/FT6R_XM30z760J4FkzNSyQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3008 Ella Blvd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "3008 Ella Blvd",
#                     "Houston, TX 77018"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77018"
#             },
#             "name": "Layne's Chicken Fingers",
#             "phone": "+17132445299",
#             "rating": 4.5,
#             "review_count": 34,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/laynes-chicken-fingers-houston?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "wood-duck-farm-cleveland",
#             "categories": [
#                 {
#                     "alias": "farmersmarket",
#                     "title": "Farmers Market"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 30.372878909111,
#                 "longitude": -95.1746644824743
#             },
#             "display_phone": "(281) 593-3642",
#             "distance": 65062.41959875722,
#             "id": "D-fh9KX_0Jbv4XHIuowd_A",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/ri6S_DsMhmlS358SWSmCmA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "270 Pine Valley Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Cleveland",
#                 "country": "US",
#                 "display_address": [
#                     "270 Pine Valley Rd",
#                     "Cleveland, TX 77328"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77328"
#             },
#             "name": "Wood Duck Farm",
#             "phone": "+12815933642",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 6,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/wood-duck-farm-cleveland?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "turkey-leg-hut-express-houston-4",
#             "categories": [
#                 {
#                     "alias": "foodtrucks",
#                     "title": "Food Trucks"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 29.952657699585,
#                 "longitude": -95.4448928833008
#             },
#             "display_phone": "",
#             "distance": 12898.155851207535,
#             "id": "kGCTJ2imfgbfm4nSuZ1aYA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/lc3vkx0R5eCGooq5f-VQdw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Houston",
#                 "country": "US",
#                 "display_address": [
#                     "Houston, TX 77067"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77067"
#             },
#             "name": "Turkey Leg Hut Express",
#             "phone": "",
#             "rating": 4.5,
#             "review_count": 10,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/turkey-leg-hut-express-houston-4?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         },
#         {
#             "alias": "beeweaver-honey-farm-navasota",
#             "categories": [
#                 {
#                     "alias": "honey",
#                     "title": "Honey"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 30.28498442702556,
#                 "longitude": -96.03226894110584
#             },
#             "display_phone": "(512) 535-2219",
#             "distance": 76894.02985820279,
#             "id": "2ZX2FD48VJtc4hgqvyqYbw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/8HMQ5IB4Cw8dYntBos30Dw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "16481 County Road 319",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Navasota",
#                 "country": "US",
#                 "display_address": [
#                     "16481 County Road 319",
#                     "Navasota, TX 77868"
#                 ],
#                 "state": "TX",
#                 "zip_code": "77868"
#             },
#             "name": "BeeWeaver Honey Farm",
#             "phone": "+15125352219",
#             "rating": 5.0,
#             "review_count": 14,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/beeweaver-honey-farm-navasota?adjust_creative=yvpDOw74EsdYOX_gzJFDZQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yvpDOw74EsdYOX_gzJFDZQ"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 29.833322107007213,
#             "longitude": -95.42724609375
#         }
#     },
#     "total": 21500
# }

# %%
counts = df['id'].count()
counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dgnil\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\dgnil\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\dgnil\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 counts = df['id'].count()
#       2 counts
#
# File c:\Users\dgnil\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\dgnil\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'id'
